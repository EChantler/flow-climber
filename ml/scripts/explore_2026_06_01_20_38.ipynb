# %% [markdown]
# # Explore raw telemetry export: 2026-06-01-20-38
#
# Loads `../data/raw/2026-06-01-20-38.csv`, filters to `data_schema_version == 6`, identifies NaN-containing rows, flattens metadata, removes rows with null values, and summarizes sessions, access tokens, difficulty reached, total time played, and time spent in each challenge label. Each row represents one 10-second telemetry window.

# %%
from pathlib import Path
import json

import numpy as np
import pandas as pd

pd.set_option("display.max_columns", 140)
pd.set_option("display.max_colwidth", 180)

DATA_PATH = Path("../data/raw/2026-06-01-20-38.csv")
SECONDS_PER_ROW = 10
assert DATA_PATH.exists(), f"Missing data file: {DATA_PATH.resolve()}"

# %% [markdown]
# ## Load, schema-filter, and inspect NaNs

# %%
raw_all = pd.read_csv(DATA_PATH)
raw_all["data_schema_version"] = pd.to_numeric(raw_all["data_schema_version"], errors="coerce")
raw_schema = raw_all[raw_all["data_schema_version"].eq(6)].copy()

nan_rows = raw_schema[raw_schema.isna().any(axis=1)].copy()
print(
    f"Raw rows: {len(raw_all):,} | "
    f"Schema 6 rows: {len(raw_schema):,} | "
    f"Schema 6 rows with any NaN: {len(nan_rows):,}"
)
display(raw_all["data_schema_version"].value_counts(dropna=False).sort_index().to_frame("rows"))
display(nan_rows.head())
display(raw_schema.isna().sum().loc[lambda s: s.gt(0)].to_frame("nan_rows"))
# Out:
# Raw rows: 1,410 | Schema 6 rows: 1,305 | Schema 6 rows with any NaN: 0
#                      rows
# data_schema_version
# 2.0                    12
# 3.0                    45
# 5.0                     9
# 6.0                  1305
# NaN                    39
# Empty DataFrame
# Columns: [id, token_used, event_type, metric_value, metadata, created_at, game_version, session_id, game_mode, window_index, window_started_at, window_ended_at, difficulty, score, height_climbed, challenge_label, data_schema_version, device_type, deployment_context]
# Index: []
# Empty DataFrame
# Columns: [nan_rows]
# Index: []

# %% [markdown]
# ## Flatten metadata and drop null rows

# %%
timestamp_cols = ["created_at", "window_started_at", "window_ended_at"]
for col in timestamp_cols:
    raw_schema[col] = pd.to_datetime(raw_schema[col], errors="coerce", utc=True)

def parse_metadata(value):
    if pd.isna(value):
        return {}
    if isinstance(value, dict):
        parsed = value
    else:
        try:
            parsed = json.loads(value)
        except json.JSONDecodeError:
            return {}
    if not isinstance(parsed, dict):
        return {}
    parsed.pop("failed_jump_counts", None)
    return parsed

metadata = pd.json_normalize(raw_schema["metadata"].map(parse_metadata)).add_prefix("meta_")
df = pd.concat([raw_schema.drop(columns=["metadata"]).reset_index(drop=True), metadata.reset_index(drop=True)], axis=1)

for col in [c for c in df.columns if c.endswith("_at") or c == "meta_logged_at"]:
    if df[col].dtype == "object":
        parsed = pd.to_datetime(df[col], errors="coerce", utc=True)
        if parsed.notna().any():
            df[col] = parsed

rows_before_dropna = len(df)
df = df.dropna(axis=0, how="any").reset_index(drop=True)
windows = df[df["event_type"].eq("telemetry_window")].copy()
windows["play_seconds"] = SECONDS_PER_ROW
windows["play_minutes"] = windows["play_seconds"] / 60

print(f"Expanded rows before dropna: {rows_before_dropna:,} | After dropna: {len(df):,} | Telemetry windows: {len(windows):,}")
display(windows.head())
display(windows.dtypes.to_frame("dtype"))
# Out:
# Expanded rows before dropna: 1,305 | After dropna: 1,305 | Telemetry windows: 1,305
#                                      id token_used        event_type  \
# 0  005420bc-6601-46d1-a39c-167020a1b0e9       5656  telemetry_window
# 1  00e009d2-a72c-4902-aed9-e852a92d7e4a    test_01  telemetry_window
# 2  010b5794-b00e-4689-87b9-592636ce6db5    test_01  telemetry_window
# 3  01168231-a9fa-4d07-bdda-4f4a54133488       2003  telemetry_window
# 4  0132eadd-88d8-4f9d-874f-d16757ee2c7b       2002  telemetry_window
#
#    metric_value                       created_at game_version  \
# 0           154 2026-05-30 12:27:47.331740+00:00     v0.15.14
# 1             8 2026-05-28 18:46:13.139322+00:00     v0.15.10
# 2            18 2026-05-24 17:54:20.479066+00:00      v0.10.0
# 3            -4 2026-06-01 11:55:41.994284+00:00     v0.15.14
# 4            -3 2026-06-01 11:54:04.093649+00:00     v0.15.14
#
#                              session_id game_mode  window_index  \
# 0  4fb7ae84-6ccd-48fd-9571-d65683a9e440     train         111.0
# 1  c06bc4ff-7384-48f3-9a0b-703b27d03933     train           6.0
# 2  577f975f-9f61-4f50-bf5d-0628bc5c029e     train           2.0
# 3  5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4     train          24.0
# 4  47967fdd-43cd-4f83-b165-2137e5d0863d     train           3.0
#
#                  window_started_at                  window_ended_at  \
# 0 2026-05-30 12:27:37.353000+00:00 2026-05-30 12:27:47.353000+00:00
# 1 2026-05-28 18:46:02.797000+00:00 2026-05-28 18:46:12.797000+00:00
# 2 2026-05-24 17:54:10.133000+00:00 2026-05-24 17:54:20.133000+00:00
# 3 2026-06-01 11:55:31.835000+00:00 2026-06-01 11:55:41.835000+00:00
# 4 2026-06-01 11:53:53.895000+00:00 2026-06-01 11:54:03.895000+00:00
#
#    difficulty  score  height_climbed           challenge_label  \
# 0        10.0  154.0         22954.0          under_challenged
# 1         7.0    8.0           677.0  appropriately_challenged
# 2         7.0   18.0          1788.0          under_challenged
# 3        10.0   -4.0          3115.0  appropriately_challenged
# 4         4.0   -3.0           125.0  appropriately_challenged
#
#    data_schema_version device_type deployment_context  meta_deaths  \
# 0                  6.0      mobile           deployed            1
# 1                  6.0      mobile           deployed            0
# 2                  6.0     desktop              local            0
# 3                  6.0      mobile           deployed            1
# 4                  6.0     desktop           deployed            1
#
#                     meta_logged_at  meta_skip_reward  meta_deaths_total  \
# 0 2026-05-30 12:27:47.362000+00:00                 0                 53
# 1 2026-05-28 18:46:12.810000+00:00                 0                  2
# 2 2026-05-24 17:54:20.148000+00:00                 0                  0
# 3 2026-06-01 11:55:41.850000+00:00                 0                 31
# 4 2026-06-01 11:54:03.906000+00:00                 0                  3
#
#    meta_jump_key_presses  meta_left_key_presses  meta_right_key_presses  \
# 0                      4                      5                       2
# 1                      0                      0                       0
# 2                      9                      7                       4
# 3                      2                      5                       1
# 4                      2                      2                       4
#
#    meta_skip_reward_total  meta_skipped_platforms  meta_seconds_since_flag  \
# 0                       0                       0                    0.393
# 1                       2                       0                   48.894
# 2                       2                       0                    0.752
# 3                       0                       0                   10.122
# 4                       0                       0                   40.000
#
#    meta_window_duration_ms  meta_previous_difficulty  \
# 0                    10000                        10
# 1                    10000                         7
# 2                    10000                         7
# 3                    10000                        10
# 4                    10000                         4
#
#    meta_vertical_position_y  meta_failed_jump_attempts  \
# 0                    -22219                          1
# 1                        70                          0
# 2                     -1050                          0
# 3                     -2137                          1
# 4                       724                          1
#
#    meta_distinct_failed_jumps  meta_flags_collected_total  \
# 0                           1                         207
# 1                           0                           8
# 2                           0                          16
# 3                           1                          27
# 4                           1                           0
#
#    meta_new_platforms_reached  meta_platform_gap_y_avg_px  \
# 0                           5                         132
# 1                           0                         123
# 2                           7                         123
# 3                           0                         132
# 4                           0                         115
#
#    meta_platform_gap_y_max_px  meta_platform_gap_y_min_px  \
# 0                         144                         120
# 1                         133                         113
# 2                         133                         113
# 3                         144                         120
# 4                         123                         107
#
#    meta_platform_width_avg_px  meta_platform_width_max_px  \
# 0                          55                          80
# 1                          60                          87
# 2                          60                          87
# 3                          55                          80
# 4                          65                          93
#
#    meta_platform_width_min_px  meta_platform_height_avg_px  \
# 0                          30                           10
# 1                          33                           10
# 2                          33                           10
# 3                          30                           10
# 4                          37                           10
#
#    meta_platform_height_max_px  meta_platform_height_min_px  \
# 0                           10                           10
# 1                           10                           10
# 2                           10                           10
# 3                           10                           10
# 4                           10                           10
#
#    meta_window_starting_height  meta_platform_x_shift_max_px  \
# 0                        22525                           250
# 1                          677                           223
# 2                         1017                           223
# 3                         2991                           250
# 4                          125                           197
#
#    meta_platform_x_shift_min_px  meta_platform_speed_px_per_frame  \
# 0                           200                              1.20
# 1                           177                              0.95
# 2                           177                              0.95
# 3                           200                              1.20
# 4                           153                              0.70
#
#    meta_total_horizontal_movement_px  meta_jumps_landed_on_new_platforms  \
# 0                               1396                                   5
# 1                                  0                                   0
# 2                               1485                                   7
# 3                                773                                   1
# 4                                347                                   0
#
#    meta_repeated_failed_jump_attempts  play_seconds  play_minutes
# 0                                   0            10      0.166667
# 1                                   0            10      0.166667
# 2                                   0            10      0.166667
# 3                                   0            10      0.166667
# 4                                   0            10      0.166667
#                                                   dtype
# id                                               object
# token_used                                       object
# event_type                                       object
# metric_value                                      int64
# created_at                          datetime64[ns, UTC]
# game_version                                     object
# session_id                                       object
# game_mode                                        object
# window_index                                    float64
# window_started_at                   datetime64[ns, UTC]
# window_ended_at                     datetime64[ns, UTC]
# difficulty                                      float64
# score                                           float64
# height_climbed                                  float64
# challenge_label                                  object
# data_schema_version                             float64
# device_type                                      object
# deployment_context                               object
# meta_deaths                                       int64
# meta_logged_at                      datetime64[ns, UTC]
# meta_skip_reward                                  int64
# meta_deaths_total                                 int64
# meta_jump_key_presses                             int64
# meta_left_key_presses                             int64
# meta_right_key_presses                            int64
# meta_skip_reward_total                            int64
# meta_skipped_platforms                            int64
# meta_seconds_since_flag                         float64
# meta_window_duration_ms                           int64
# meta_previous_difficulty                          int64
# meta_vertical_position_y                          int64
# meta_failed_jump_attempts                         int64
# meta_distinct_failed_jumps                        int64
# meta_flags_collected_total                        int64
# meta_new_platforms_reached                        int64
# meta_platform_gap_y_avg_px                        int64
# meta_platform_gap_y_max_px                        int64
# meta_platform_gap_y_min_px                        int64
# meta_platform_width_avg_px                        int64
# meta_platform_width_max_px                        int64
# meta_platform_width_min_px                        int64
# meta_platform_height_avg_px                       int64
# meta_platform_height_max_px                       int64
# meta_platform_height_min_px                       int64
# meta_window_starting_height                       int64
# meta_platform_x_shift_max_px                      int64
# meta_platform_x_shift_min_px                      int64
# meta_platform_speed_px_per_frame                float64
# meta_total_horizontal_movement_px                 int64
# meta_jumps_landed_on_new_platforms                int64
# meta_repeated_failed_jump_attempts                int64
# play_seconds                                      int64
# play_minutes                                    float64

# %% [markdown]
# ## Buckets: sessions, access tokens, difficulty reached

# %%
def add_duration_bucket(frame, count_col="rows"):
    bins = [0, 1, 3, 6, 12, 30, 60, 120, np.inf]
    labels = ["10s", "20–30s", "40–60s", "1–2m", "2–5m", "5–10m", "10–20m", "20m+"]
    return pd.cut(frame[count_col], bins=bins, labels=labels, include_lowest=True)

session_summary = (
    windows.groupby("session_id", dropna=False)
    .agg(
        rows=("id", "count"),
        token_used=("token_used", lambda s: s.mode().iat[0] if not s.mode().empty else np.nan),
        started_at=("created_at", "min"),
        ended_at=("created_at", "max"),
        max_difficulty=("difficulty", "max"),
        min_difficulty=("difficulty", "min"),
        max_score=("score", "max"),
        max_height=("height_climbed", "max"),
    )
    .assign(play_seconds=lambda x: x["rows"] * SECONDS_PER_ROW, play_minutes=lambda x: x["play_seconds"] / 60)
    .sort_values(["rows", "max_score"], ascending=False)
)
session_summary["duration_bucket"] = add_duration_bucket(session_summary)

token_summary = (
    windows.groupby("token_used", dropna=False)
    .agg(
        rows=("id", "count"),
        sessions=("session_id", "nunique"),
        started_at=("created_at", "min"),
        ended_at=("created_at", "max"),
        max_difficulty=("difficulty", "max"),
        max_score=("score", "max"),
        max_height=("height_climbed", "max"),
    )
    .assign(play_seconds=lambda x: x["rows"] * SECONDS_PER_ROW, play_minutes=lambda x: x["play_seconds"] / 60)
    .sort_values(["rows", "sessions"], ascending=False)
)
token_summary["duration_bucket"] = add_duration_bucket(token_summary)

print(f"Sessions: {len(session_summary):,}")
display(session_summary.head(30))
display(session_summary["duration_bucket"].value_counts().sort_index().to_frame("sessions"))

print(f"Access tokens: {len(token_summary):,}")
display(token_summary)
display(token_summary["duration_bucket"].value_counts().sort_index().to_frame("access_tokens"))

print("Difficulty reached by session")
display(session_summary["max_difficulty"].value_counts().sort_index().rename_axis("max_difficulty").to_frame("sessions"))

print("Difficulty reached by access token")
display(token_summary["max_difficulty"].value_counts().sort_index().rename_axis("max_difficulty").to_frame("access_tokens"))
# Out:
# Sessions: 68
#                                       rows token_used  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440   137       5656
# 1779812316142-1873bcf186bbc             85    test_01
# e59157d0-810f-41b2-92c2-436a1658f3eb    63    jeannie
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3    62       2002
# f9a85d54-1b7f-456a-aa6b-ff9aca727820    57       2434
# 5d47e94b-d860-43ed-b550-b4c8f7f69686    55       7676
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec
# 2003       2026-06-01 12:00:42.007964+00:00            10.0       15.0
# 2005       2026-06-01 12:46:38.295478+00:00            10.0       12.0
# 2007       2026-06-01 12:38:50.532335+00:00            10.0       56.0
# bea        2026-05-31 07:20:09.578979+00:00            10.0        3.0
# 2001       2026-06-01 12:02:48.086166+00:00            10.0        1.0
# claude     2026-05-31 07:06:13.650056+00:00            10.0        0.0
# jaco       2026-05-31 13:41:49.942474+00:00            10.0       21.0
# sas_1905   2026-05-26 20:33:49.857936+00:00             5.0       18.0
# cupuashoe  2026-05-27 18:19:33.484389+00:00             2.0       11.0
#
#             max_height  play_seconds  play_minutes duration_bucket
# token_used
# test_01        13855.0          2900     48.333333            20m+
# 5656           30089.0          2540     42.333333            20m+
# jeannie         8178.0          1310     21.833333            20m+
# 7676           20641.0          1090     18.166667          10–20m
# 2002            7586.0           960     16.000000          10–20m
# 2434            5129.0           840     14.000000          10–20m
# 7278            7194.0           660     11.000000          10–20m
# 2003            8697.0           550      9.166667           5–10m
# 2005            2496.0           530      8.833333           5–10m
# 2007            9883.0           520      8.666667           5–10m
# bea              470.0           320      5.333333           5–10m
# 2001             450.0           310      5.166667           5–10m
# claude          1483.0           180      3.000000            2–5m
# jaco            3738.0           180      3.000000            2–5m
# sas_1905        2149.0           140      2.333333            2–5m
# cupuashoe        954.0            20      0.333333          20–30s
#                  access_tokens
# duration_bucket
# 10s                          0
# 20–30s                       1
# 40–60s                       0
# 1–2m                         0
# 2–5m                         3
# 5–10m                        5
# 10–20m                       4
# 20m+                         3
# Difficulty reached by session
#                 sessions
# max_difficulty
# 1.0                    8
# 2.0                    8
# 3.0                    5
# 4.0                    3
# 5.0                    3
# 6.0                    2
# 7.0                    1
# 9.0                    3
# 10.0                  35
# Difficulty reached by access token
#                 access_tokens
# max_difficulty
# 2.0                         1
# 5.0                         1
# 10.0                       14

# %% [markdown]
# ## Data entries by difficulty

# %%
difficulty_counts = (
    windows["difficulty"]
    .value_counts(dropna=False)
    .reindex(range(1, 11), fill_value=0)
    .rename_axis("difficulty")
    .to_frame("rows")
)
difficulty_counts["play_seconds"] = difficulty_counts["rows"] * SECONDS_PER_ROW
difficulty_counts["play_minutes"] = difficulty_counts["play_seconds"] / 60
display(difficulty_counts)

entry_cols = [
    "id", "created_at", "token_used", "session_id", "game_mode", "challenge_label",
    "device_type", "difficulty", "score", "height_climbed", "window_index",
]
entry_cols = [col for col in entry_cols if col in windows]
for difficulty in range(1, 11):
    difficulty_rows = windows[windows["difficulty"].eq(difficulty)].sort_values("created_at")
    print(f"\nDifficulty {difficulty}: {len(difficulty_rows):,} rows")
    display(difficulty_rows[entry_cols].head(20))
# Out:
#             rows  play_seconds  play_minutes
# difficulty
# 1            166          1660     27.666667
# 2             62           620     10.333333
# 3             53           530      8.833333
# 4             46           460      7.666667
# 5             46           460      7.666667
# 6             45           450      7.500000
# 7             44           440      7.333333
# 8             42           420      7.000000
# 9             43           430      7.166667
# 10           758          7580    126.333333
# Difficulty 1: 166 rows
#                                         id                       created_at  \
test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 1009    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 742     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 590     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 663     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 513            over_challenged     desktop        10.0   27.0          2941.0
# 477           under_challenged     desktop        10.0   34.0          3769.0
# 779           under_challenged     desktop        10.0   37.0          4066.0
# 1184          under_challenged     desktop        10.0   40.0          4358.0
# 698            over_challenged     desktop        10.0   40.0          4358.0
# 950           under_challenged     desktop        10.0   45.0          4905.0
# 638   appropriately_challenged     desktop        10.0   50.0          5553.0
# 584   appropriately_challenged     desktop        10.0   54.0          6121.0
# 134           under_challenged     desktop        10.0   59.0          6756.0
# 360           under_challenged     desktop        10.0   61.0          6048.0
# 452           under_challenged     desktop        10.0   69.0          6910.0
# 844           under_challenged     desktop        10.0   73.0          7575.0
# 711           under_challenged     desktop        10.0   76.0          7823.0
# 1126          under_challenged     desktop        10.0   78.0          8067.0
# 306            over_challenged     desktop        10.0   78.0          8067.0
# 1190          under_challenged     desktop        10.0   53.0          6488.0
# 1009          under_challenged     desktop        10.0   58.0          7029.0
# 742           under_challenged     desktop        10.0   61.0          7277.0
# 590           under_challenged     desktop        10.0   68.0          7983.0
# 663           under_challenged     desktop        10.0   72.0          8614.0
#
#       window_index
# 513            5.0
# 477            6.0
# 779            7.0
# 1184           8.0
# 698            9.0
# 950           10.0
# 638           11.0
# 584           12.0
# 134           13.0
# 360           10.0
# 452           11.0
# 844           12.0
# 711           13.0
# 1126          14.0
# 306           15.0
# 1190          14.0
# 1009          15.0
# 742           16.0
# 590           17.0
# 663           18.0

# %% [markdown]
# ## Time played and time spent by challenge label

# %%
total_rows = len(windows)
total_seconds = total_rows * SECONDS_PER_ROW
print(f"Total telemetry windows: {total_rows:,}")
print(f"Total play time: {total_seconds:,} seconds | {total_seconds / 60:,.1f} minutes | {total_seconds / 3600:,.2f} hours")

label_time = (
    windows.groupby("challenge_label", dropna=False)
    .agg(rows=("id", "count"), sessions=("session_id", "nunique"), access_tokens=("token_used", "nunique"))
    .assign(
        play_seconds=lambda x: x["rows"] * SECONDS_PER_ROW,
        play_minutes=lambda x: x["play_seconds"] / 60,
        play_hours=lambda x: x["play_seconds"] / 3600,
        share=lambda x: x["rows"] / total_rows,
    )
    .sort_values("rows", ascending=False)
)
display(label_time)

session_time_stats = session_summary[["rows", "play_seconds", "play_minutes", "max_difficulty", "max_score", "max_height"]].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).T
token_time_stats = token_summary[["rows", "sessions", "play_seconds", "play_minutes", "max_difficulty", "max_score", "max_height"]].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).T

print("Session time/play stats")
display(session_time_stats)
print("Access token time/play stats")
display(token_time_stats)

session_label_time = pd.crosstab(windows["session_id"], windows["challenge_label"]) * SECONDS_PER_ROW
session_label_time = session_label_time.add_suffix("_seconds")
session_label_time["total_seconds"] = session_label_time.sum(axis=1)
display(session_label_time.sort_values("total_seconds", ascending=False).head(30))

token_label_time = pd.crosstab(windows["token_used"], windows["challenge_label"]) * SECONDS_PER_ROW
token_label_time = token_label_time.add_suffix("_seconds")
token_label_time["total_seconds"] = token_label_time.sum(axis=1)
display(token_label_time.sort_values("total_seconds", ascending=False))
# Out:
# Total telemetry windows: 1,305
# Total play time: 13,050 seconds | 217.5 minutes | 3.62 hours
#                           rows  sessions  access_tokens  play_seconds  \
# challenge_label
# appropriately_challenged   591        56             15          5910
# under_challenged           460        59             15          4600
# over_challenged            254        40             14          2540
#
#                           play_minutes  play_hours     share
# challenge_label
# appropriately_challenged     98.500000    1.641667  0.452874
# under_challenged             76.666667    1.277778  0.352490
# over_challenged              42.333333    0.705556  0.194636
# Session time/play stats
#                 count         mean          std        min          5%  \
# rows             68.0    19.191176    23.687176   1.000000    1.000000
# play_seconds     68.0   191.911765   236.871760  10.000000   10.000000
# play_minutes     68.0     3.198529     3.947863   0.166667    0.166667
# max_difficulty   68.0     6.794118     3.731907   1.000000    1.000000
# max_score        68.0    24.852941    35.146289  -1.000000    0.000000
# max_height       68.0  3842.205882  5127.134795   0.000000  130.000000
#
#                    25%          50%       75%           95%           max
# rows              3.00    10.000000    26.250     60.250000    137.000000
# play_seconds     30.00   100.000000   262.500    602.500000   1370.000000
# play_minutes      0.50     1.666667     4.375     10.041667     22.833333
# max_difficulty    3.00    10.000000    10.000     10.000000     10.000000
# max_score         4.75    12.000000    30.750     94.150000    202.000000
# max_height      774.75  1947.000000  5144.250  12638.950000  30089.000000
# Access token time/play stats
#                 count        mean          std         min          5%  \
# rows             16.0    81.56250    82.952974    2.000000   11.000000
# sessions         16.0     4.25000     6.148170    1.000000    1.000000
# play_seconds     16.0   815.62500   829.529736   20.000000  110.000000
# play_minutes     16.0    13.59375    13.825496    0.333333    1.833333
# max_difficulty   16.0     9.18750     2.286737    2.000000    4.250000
# max_score        16.0    43.56250    57.831904    0.000000    0.000000
# max_height       16.0  7687.00000  8091.447518  450.000000  465.000000
#
#                      25%     50%          75%           95%           max
# rows              27.750    54.0    99.250000    263.000000    290.000000
# sessions           1.000     3.0     3.250000     13.250000     26.000000
# play_seconds     277.500   540.0   992.500000   2630.000000   2900.000000
# play_minutes       4.625     9.0    16.541667     43.833333     48.333333
# max_difficulty    10.000    10.0    10.000000     10.000000     10.000000
# max_score          9.000    18.0    55.250000    152.500000    202.000000
# max_height      1982.500  6161.5  8993.500000  23003.000000  30089.000000
# challenge_label                       appropriately_challenged_seconds  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440                               540
# 1779812316142-1873bcf186bbc                                         10
# e59157d0-810f-41b2-92c2-436a1658f3eb                               400
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3                               260
# f9a85d54-1b7f-456a-aa6b-ff9aca727820                               410
# 5d47e94b-d860-43ed-b550-b4c8f7f69686                               200
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4                               200
# 06a90f93-d0e4-45fa-bd98-13678e749829                               280
# 1779813177540-23369a30a10fe                                         80
# 9c80face-f1d4-4cf1-b795-e7522cf68626                               210
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c                               190
# 1779826329595-9fdf705124d1f8                                        70
# 47967fdd-43cd-4f83-b165-2137e5d0863d                               290
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471                               300
# 8952ae20-5054-4644-9dda-66dc1bf61776                                60
# 102b2e6a-c403-419b-b82e-626a8790dd79                               110
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9                               180
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd                               100
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2                                80
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd                               210
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70                               150
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2
# e01272f0-e03d-4483-9e1d-199cc1c16778                        40            140
# challenge_label  appropriately_challenged_seconds  over_challenged_seconds  \
# token_used
# test_01                                       680                     1050
# 5656                                          960                      190
# jeannie                                       720                      230
# 7676                                          480                       90
# 2002                                          560                      290
# 2434                                          590                      140
# 7278                                          440                       60
# 2003                                          200                      170
# 2005                                          320                       60
# 2007                                          210                       80
# bea                                           300                       20
# 2001                                          260                       40
# jaco                                           60                       30
# claude                                         80                       90
# sas_1905                                       50                        0
# cupuashoe                                       0                        0
#
# challenge_label  under_challenged_seconds  total_seconds
# token_used
# test_01                              1170           2900
# 5656                                 1390           2540
# jeannie                               360           1310
# 7676                                  520           1090
# 2002                                  110            960
# 2434                                  110            840
# 7278                                  160            660
# 2003                                  180            550
# 2005                                  150            530
# 2007                                  230            520
# bea                                     0            320
# 2001                                   10            310
# jaco                                   90            180
# claude                                 10            180
# sas_1905                               90            140
# cupuashoe                              20             20

# %% [markdown]
# ## Challenge label by difficulty

# %%
difficulty_label_counts = pd.crosstab(windows["difficulty"], windows["challenge_label"], margins=True)
difficulty_label_share = pd.crosstab(windows["difficulty"], windows["challenge_label"], normalize="index").round(3)
display(difficulty_label_counts)
display(difficulty_label_share)

try:
    import matplotlib.pyplot as plt

    plot_counts = pd.crosstab(windows["difficulty"], windows["challenge_label"]).reindex(range(1, 11), fill_value=0)
    colors = {
        "over_challenged": "orange",
        "under_challenged": "blue",
        "appropriately_challenged": "green",
    }

    fig, ax = plt.subplots(figsize=(10, 5))
    for label, color in colors.items():
        if label in plot_counts:
            ax.plot(
                plot_counts.index,
                plot_counts[label],
                marker="o",
                linewidth=2,
                color=color,
                label=label.replace("_", " "),
            )

    ax.set_title("Challenge label counts by difficulty")
    ax.set_xlabel("Difficulty")
    ax.set_ylabel("Rows / 10-second windows")
    ax.set_xticks(range(1, 11))
    ax.grid(True, alpha=0.25)
    ax.legend()
    plt.show()
except ImportError:
    print("matplotlib is not installed in this environment; skipping challenge-label line chart.")
# Out:
# challenge_label  appropriately_challenged  over_challenged  under_challenged  \
# difficulty
# 1.0                                    32               85                49
# 2.0                                    27                8                27
# 3.0                                    19                8                26
# 4.0                                    24                3                19
# 5.0                                    21                3                22
# 6.0                                    22                6                17
# 7.0                                    22                6                16
# 8.0                                    17               10                15
# 9.0                                    20                4                19
# 10.0                                  387              121               250
# All                                   591              254               460
#
# challenge_label   All
# difficulty
# 1.0               166
# 2.0                62
# 3.0                53
# 4.0                46
# 5.0                46
# 6.0                45
# 7.0                44
# 8.0                42
# 9.0                43
# 10.0              758
# All              1305
# challenge_label  appropriately_challenged  over_challenged  under_challenged
# difficulty
# 1.0                                 0.193            0.512             0.295
# 2.0                                 0.435            0.129             0.435
# 3.0                                 0.358            0.151             0.491
# 4.0                                 0.522            0.065             0.413
# 5.0                                 0.457            0.065             0.478
# 6.0                                 0.489            0.133             0.378
# 7.0                                 0.500            0.136             0.364
# 8.0                                 0.405            0.238             0.357
# 9.0                                 0.465            0.093             0.442
# 10.0                                0.511            0.160             0.330
