# %% [markdown]
# # Explore raw telemetry export: 2026-06-02-20-08
#
# Loads `../data/raw/2026-06-02-20-08.csv`, filters to `data_schema_version == 6`, identifies NaN-containing rows, flattens metadata, removes rows with null values, and summarizes sessions, access tokens, difficulty reached, total time played, and time spent in each challenge label. Each row represents one 10-second telemetry window.

# %%
from pathlib import Path
import json

import numpy as np
import pandas as pd

pd.set_option("display.max_columns", 140)
pd.set_option("display.max_colwidth", 180)

DATA_PATH = Path("../data/raw/2026-06-02-20-08.csv")
SECONDS_PER_ROW = 10
assert DATA_PATH.exists(), f"Missing data file: {DATA_PATH.resolve()}"

# %% [markdown]
# ## Load, schema-filter, and inspect NaNs

# %%
raw_all = pd.read_csv(DATA_PATH)
raw_all["data_schema_version"] = pd.to_numeric(raw_all["data_schema_version"], errors="coerce")
raw_schema = raw_all[raw_all["data_schema_version"].eq(6)].copy()

nan_rows = raw_schema[raw_schema.isna().any(axis=1)].copy()
print(
    f"Raw rows: {len(raw_all):,} | "
    f"Schema 6 rows: {len(raw_schema):,} | "
    f"Schema 6 rows with any NaN: {len(nan_rows):,}"
)
display(raw_all["data_schema_version"].value_counts(dropna=False).sort_index().to_frame("rows"))
display(nan_rows.head())
display(raw_schema.isna().sum().loc[lambda s: s.gt(0)].to_frame("nan_rows"))
# Out:
# Raw rows: 1,821 | Schema 6 rows: 1,716 | Schema 6 rows with any NaN: 0
#                      rows
# data_schema_version
# 2.0                    12
# 3.0                    45
# 5.0                     9
# 6.0                  1716
# NaN                    39
# Empty DataFrame
# Columns: [id, token_used, event_type, metric_value, metadata, created_at, game_version, session_id, game_mode, window_index, window_started_at, window_ended_at, difficulty, score, height_climbed, challenge_label, data_schema_version, device_type, deployment_context]
# Index: []
# Empty DataFrame
# Columns: [nan_rows]
# Index: []

# %% [markdown]
# ## Flatten metadata and drop null rows

# %%
timestamp_cols = ["created_at", "window_started_at", "window_ended_at"]
for col in timestamp_cols:
    raw_schema[col] = pd.to_datetime(raw_schema[col], errors="coerce", utc=True)

def parse_metadata(value):
    if pd.isna(value):
        return {}
    if isinstance(value, dict):
        parsed = value
    else:
        try:
            parsed = json.loads(value)
        except json.JSONDecodeError:
            return {}
    if not isinstance(parsed, dict):
        return {}
    parsed.pop("failed_jump_counts", None)
    return parsed

metadata = pd.json_normalize(raw_schema["metadata"].map(parse_metadata)).add_prefix("meta_")
df = pd.concat([raw_schema.drop(columns=["metadata"]).reset_index(drop=True), metadata.reset_index(drop=True)], axis=1)

for col in [c for c in df.columns if c.endswith("_at") or c == "meta_logged_at"]:
    if df[col].dtype == "object":
        parsed = pd.to_datetime(df[col], errors="coerce", utc=True)
        if parsed.notna().any():
            df[col] = parsed

rows_before_dropna = len(df)
df = df.dropna(axis=0, how="any").reset_index(drop=True)
windows = df[df["event_type"].eq("telemetry_window")].copy()
windows["play_seconds"] = SECONDS_PER_ROW
windows["play_minutes"] = windows["play_seconds"] / 60

print(f"Expanded rows before dropna: {rows_before_dropna:,} | After dropna: {len(df):,} | Telemetry windows: {len(windows):,}")
display(windows.head())
display(windows.dtypes.to_frame("dtype"))
# Out:
# Expanded rows before dropna: 1,716 | After dropna: 1,716 | Telemetry windows: 1,716
#                                      id token_used        event_type  \
# 0  005420bc-6601-46d1-a39c-167020a1b0e9       5656  telemetry_window
# 1  00e009d2-a72c-4902-aed9-e852a92d7e4a    test_01  telemetry_window
# 2  010b5794-b00e-4689-87b9-592636ce6db5    test_01  telemetry_window
# 3  01168231-a9fa-4d07-bdda-4f4a54133488       2003  telemetry_window
# 4  0132eadd-88d8-4f9d-874f-d16757ee2c7b       2002  telemetry_window
#
#    metric_value                       created_at game_version  \
# 0           154 2026-05-30 12:27:47.331740+00:00     v0.15.14
# 1             8 2026-05-28 18:46:13.139322+00:00     v0.15.10
# 2            18 2026-05-24 17:54:20.479066+00:00      v0.10.0
# 3            -4 2026-06-01 11:55:41.994284+00:00     v0.15.14
# 4            -3 2026-06-01 11:54:04.093649+00:00     v0.15.14
#
#                              session_id game_mode  window_index  \
# 0  4fb7ae84-6ccd-48fd-9571-d65683a9e440     train         111.0
# 1  c06bc4ff-7384-48f3-9a0b-703b27d03933     train           6.0
# 2  577f975f-9f61-4f50-bf5d-0628bc5c029e     train           2.0
# 3  5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4     train          24.0
# 4  47967fdd-43cd-4f83-b165-2137e5d0863d     train           3.0
#
#                  window_started_at                  window_ended_at  \
# 0 2026-05-30 12:27:37.353000+00:00 2026-05-30 12:27:47.353000+00:00
# 1 2026-05-28 18:46:02.797000+00:00 2026-05-28 18:46:12.797000+00:00
# 2 2026-05-24 17:54:10.133000+00:00 2026-05-24 17:54:20.133000+00:00
# 3 2026-06-01 11:55:31.835000+00:00 2026-06-01 11:55:41.835000+00:00
# 4 2026-06-01 11:53:53.895000+00:00 2026-06-01 11:54:03.895000+00:00
#
#    difficulty  score  height_climbed           challenge_label  \
# 0        10.0  154.0         22954.0          under_challenged
# 1         7.0    8.0           677.0  appropriately_challenged
# 2         7.0   18.0          1788.0          under_challenged
# 3        10.0   -4.0          3115.0  appropriately_challenged
# 4         4.0   -3.0           125.0  appropriately_challenged
#
#    data_schema_version device_type deployment_context  meta_deaths  \
# 0                  6.0      mobile           deployed            1
# 1                  6.0      mobile           deployed            0
# 2                  6.0     desktop              local            0
# 3                  6.0      mobile           deployed            1
# 4                  6.0     desktop           deployed            1
#
#                     meta_logged_at  meta_skip_reward  meta_deaths_total  \
# 0 2026-05-30 12:27:47.362000+00:00                 0                 53
# 1 2026-05-28 18:46:12.810000+00:00                 0                  2
# 2 2026-05-24 17:54:20.148000+00:00                 0                  0
# 3 2026-06-01 11:55:41.850000+00:00                 0                 31
# 4 2026-06-01 11:54:03.906000+00:00                 0                  3
#
#    meta_jump_key_presses  meta_left_key_presses  meta_right_key_presses  \
# 0                      4                      5                       2
# 1                      0                      0                       0
# 2                      9                      7                       4
# 3                      2                      5                       1
# 4                      2                      2                       4
#
#    meta_skip_reward_total  meta_skipped_platforms  meta_seconds_since_flag  \
# 0                       0                       0                    0.393
# 1                       2                       0                   48.894
# 2                       2                       0                    0.752
# 3                       0                       0                   10.122
# 4                       0                       0                   40.000
#
#    meta_window_duration_ms  meta_previous_difficulty  \
# 0                    10000                        10
# 1                    10000                         7
# 2                    10000                         7
# 3                    10000                        10
# 4                    10000                         4
#
#    meta_vertical_position_y  meta_failed_jump_attempts  \
# 0                    -22219                          1
# 1                        70                          0
# 2                     -1050                          0
# 3                     -2137                          1
# 4                       724                          1
#
#    meta_distinct_failed_jumps  meta_flags_collected_total  \
# 0                           1                         207
# 1                           0                           8
# 2                           0                          16
# 3                           1                          27
# 4                           1                           0
#
#    meta_new_platforms_reached  meta_platform_gap_y_avg_px  \
# 0                           5                         132
# 1                           0                         123
# 2                           7                         123
# 3                           0                         132
# 4                           0                         115
#
#    meta_platform_gap_y_max_px  meta_platform_gap_y_min_px  \
# 0                         144                         120
# 1                         133                         113
# 2                         133                         113
# 3                         144                         120
# 4                         123                         107
#
#    meta_platform_width_avg_px  meta_platform_width_max_px  \
# 0                          55                          80
# 1                          60                          87
# 2                          60                          87
# 3                          55                          80
# 4                          65                          93
#
#    meta_platform_width_min_px  meta_platform_height_avg_px  \
# 0                          30                           10
# 1                          33                           10
# 2                          33                           10
# 3                          30                           10
# 4                          37                           10
#
#    meta_platform_height_max_px  meta_platform_height_min_px  \
# 0                           10                           10
# 1                           10                           10
# 2                           10                           10
# 3                           10                           10
# 4                           10                           10
#
#    meta_window_starting_height  meta_platform_x_shift_max_px  \
# 0                        22525                           250
# 1                          677                           223
# 2                         1017                           223
# 3                         2991                           250
# 4                          125                           197
#
#    meta_platform_x_shift_min_px  meta_platform_speed_px_per_frame  \
# 0                           200                              1.20
# 1                           177                              0.95
# 2                           177                              0.95
# 3                           200                              1.20
# 4                           153                              0.70
#
#    meta_total_horizontal_movement_px  meta_jumps_landed_on_new_platforms  \
# 0                               1396                                   5
# 1                                  0                                   0
# 2                               1485                                   7
# 3                                773                                   1
# 4                                347                                   0
#
#    meta_repeated_failed_jump_attempts  play_seconds  play_minutes
# 0                                   0            10      0.166667
# 1                                   0            10      0.166667
# 2                                   0            10      0.166667
# 3                                   0            10      0.166667
# 4                                   0            10      0.166667
#                                                   dtype
# id                                               object
# token_used                                       object
# event_type                                       object
# metric_value                                      int64
# created_at                          datetime64[ns, UTC]
# game_version                                     object
# session_id                                       object
# game_mode                                        object
# window_index                                    float64
# window_started_at                   datetime64[ns, UTC]
# window_ended_at                     datetime64[ns, UTC]
# difficulty                                      float64
# score                                           float64
# height_climbed                                  float64
# challenge_label                                  object
# data_schema_version                             float64
# device_type                                      object
# deployment_context                               object
# meta_deaths                                       int64
# meta_logged_at                      datetime64[ns, UTC]
# meta_skip_reward                                  int64
# meta_deaths_total                                 int64
# meta_jump_key_presses                             int64
# meta_left_key_presses                             int64
# meta_right_key_presses                            int64
# meta_skip_reward_total                            int64
# meta_skipped_platforms                            int64
# meta_seconds_since_flag                         float64
# meta_window_duration_ms                           int64
# meta_previous_difficulty                          int64
# meta_vertical_position_y                          int64
# meta_failed_jump_attempts                         int64
# meta_distinct_failed_jumps                        int64
# meta_flags_collected_total                        int64
# meta_new_platforms_reached                        int64
# meta_platform_gap_y_avg_px                        int64
# meta_platform_gap_y_max_px                        int64
# meta_platform_gap_y_min_px                        int64
# meta_platform_width_avg_px                        int64
# meta_platform_width_max_px                        int64
# meta_platform_width_min_px                        int64
# meta_platform_height_avg_px                       int64
# meta_platform_height_max_px                       int64
# meta_platform_height_min_px                       int64
# meta_window_starting_height                       int64
# meta_platform_x_shift_max_px                      int64
# meta_platform_x_shift_min_px                      int64
# meta_platform_speed_px_per_frame                float64
# meta_total_horizontal_movement_px                 int64
# meta_jumps_landed_on_new_platforms                int64
# meta_repeated_failed_jump_attempts                int64
# play_seconds                                      int64
# play_minutes                                    float64

# %% [markdown]
# ## Buckets: sessions, access tokens, difficulty reached

# %%
def add_duration_bucket(frame, count_col="rows"):
    bins = [0, 1, 3, 6, 12, 30, 60, 120, np.inf]
    labels = ["10s", "20–30s", "40–60s", "1–2m", "2–5m", "5–10m", "10–20m", "20m+"]
    return pd.cut(frame[count_col], bins=bins, labels=labels, include_lowest=True)

session_summary = (
    windows.groupby("session_id", dropna=False)
    .agg(
        rows=("id", "count"),
        token_used=("token_used", lambda s: s.mode().iat[0] if not s.mode().empty else np.nan),
        started_at=("created_at", "min"),
        ended_at=("created_at", "max"),
        max_difficulty=("difficulty", "max"),
        min_difficulty=("difficulty", "min"),
        max_score=("score", "max"),
        max_height=("height_climbed", "max"),
    )
    .assign(play_seconds=lambda x: x["rows"] * SECONDS_PER_ROW, play_minutes=lambda x: x["play_seconds"] / 60)
    .sort_values(["rows", "max_score"], ascending=False)
)
session_summary["duration_bucket"] = add_duration_bucket(session_summary)

token_summary = (
    windows.groupby("token_used", dropna=False)
    .agg(
        rows=("id", "count"),
        sessions=("session_id", "nunique"),
        started_at=("created_at", "min"),
        ended_at=("created_at", "max"),
        max_difficulty=("difficulty", "max"),
        max_score=("score", "max"),
        max_height=("height_climbed", "max"),
    )
    .assign(play_seconds=lambda x: x["rows"] * SECONDS_PER_ROW, play_minutes=lambda x: x["play_seconds"] / 60)
    .sort_values(["rows", "sessions"], ascending=False)
)
token_summary["duration_bucket"] = add_duration_bucket(token_summary)

print(f"Sessions: {len(session_summary):,}")
display(session_summary.head(30))
display(session_summary["duration_bucket"].value_counts().sort_index().to_frame("sessions"))

print(f"Access tokens: {len(token_summary):,}")
display(token_summary)
display(token_summary["duration_bucket"].value_counts().sort_index().to_frame("access_tokens"))

print("Difficulty reached by session")
display(session_summary["max_difficulty"].value_counts().sort_index().rename_axis("max_difficulty").to_frame("sessions"))

print("Difficulty reached by access token")
display(token_summary["max_difficulty"].value_counts().sort_index().rename_axis("max_difficulty").to_frame("access_tokens"))
# Out:
# Sessions: 77
#                                       rows token_used  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440   137       5656
# 56915d3a-01b4-437c-9166-b6d62b7da9db   119  cupuashoe
# aebf0163-b8df-45d1-b834-50d62e09591e   104       2007
# 1779812316142-1873bcf186bbc             85    test_01
# e59157d0-810f-41b2-92c2-436a1658f3eb    63    jeannie
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3    62       2002
# f9a85d54-1b7f-456a-aa6b-ff9aca727820    57       2434
# 5d47e94b-d860-43ed-b550-b4c8f7f69686    55       7676
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4    55       2003
# 06a90f93-d0e4-45fa-bd98-13678e749829    54       7676
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74    52  cupuashoe
# 83ae3cec-79b9-4c3b-966c-376d090b18b1    44       2013
# 1779813177540-23369a30a10fe             43    test_01
# 9c80face-f1d4-4cf1-b795-e7522cf68626    41    jeannie
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c    36       7278
# 1779826329595-9fdf705124d1f8            35    test_01
# dc71c15c-9338-4a7b-8f44-b8610848bb2b    33       2019
# 47967fdd-43cd-4f83-b165-2137e5d0863d    33       2002
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471    32        bea
# 8952ae20-5054-4644-9dda-66dc1bf61776    28       2007
# d31bcf45-c5f9-49c2-b279-51f999149198    28       2007
# 102b2e6a-c403-419b-b82e-626a8790dd79    27    jeannie
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9    27       2434
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd    26       5656
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2    25       5656
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd    22       2001
# 163931f4-ee12-42d5-ad52-c7a11345df25    21       2015
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70    20    test_01
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d    20       7278
# a7e24744-5e70-4724-abfb-3a4af25d0531    18       jaco
#
#                                                            started_at  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440 2026-05-30 11:56:29.918545+00:00
# 56915d3a-01b4-437c-9166-b6d62b7da9db 2026-06-02 02:15:35.741357+00:00
# aebf0163-b8df-45d1-b834-50d62e09591e 2026-06-02 15:16:26.875068+00:00
# 1779812316142-1873bcf186bbc          2026-05-26 16:18:49.500311+00:00
# e59157d0-810f-41b2-92c2-436a1658f3eb 2026-05-31 06:55:46.450566+00:00
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3 2026-06-01 12:02:47.756331+00:00
# f9a85d54-1b7f-456a-aa6b-ff9aca727820 2026-05-30 12:01:06.801936+00:00
# 5d47e94b-d860-43ed-b550-b4c8f7f69686 2026-05-30 14:39:29.472275+00:00
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4 2026-06-01 11:51:42.028014+00:00
# 06a90f93-d0e4-45fa-bd98-13678e749829 2026-05-30 11:56:27.205939+00:00
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74 2026-06-02 02:06:29.753087+00:00
# 83ae3cec-79b9-4c3b-966c-376d090b18b1 2026-06-02 10:45:15.073077+00:00
# 1779813177540-23369a30a10fe          2026-05-26 16:33:20.635627+00:00
# 9c80face-f1d4-4cf1-b795-e7522cf68626 2026-05-31 08:03:37.472483+00:00
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c 2026-05-28 19:59:28.456066+00:00
# 1779826329595-9fdf705124d1f8         2026-05-26 20:12:21.233288+00:00
# dc71c15c-9338-4a7b-8f44-b8610848bb2b 2026-06-02 13:05:19.079477+00:00
# 47967fdd-43cd-4f83-b165-2137e5d0863d 2026-06-01 11:53:34.163681+00:00
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471 2026-05-31 07:14:59.597579+00:00
# 8952ae20-5054-4644-9dda-66dc1bf61776 2026-06-01 12:34:20.655531+00:00
# d31bcf45-c5f9-49c2-b279-51f999149198 2026-06-02 10:39:57.196580+00:00
# 102b2e6a-c403-419b-b82e-626a8790dd79 2026-05-31 07:59:00.710069+00:00
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9 2026-05-30 11:56:33.907756+00:00
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd 2026-05-30 18:03:37.002255+00:00
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2 2026-05-30 15:40:15.402684+00:00
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd 2026-06-01 11:59:18.118691+00:00
# 163931f4-ee12-42d5-ad52-c7a11345df25 2026-06-02 15:10:52.440414+00:00
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70 2026-05-28 18:41:50.390534+00:00
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d 2026-05-28 20:12:02.268143+00:00
# a7e24744-5e70-4724-abfb-3a4af25d0531 2026-05-31 12:39:26.080810+00:00
#
#                                                              ended_at  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440 2026-05-30 12:31:57.333305+00:00
# 56915d3a-01b4-437c-9166-b6d62b7da9db 2026-06-02 04:12:41.250865+00:00
# aebf0163-b8df-45d1-b834-50d62e09591e 2026-06-02 15:33:36.883811+00:00
# 1779812316142-1873bcf186bbc          2026-05-26 16:32:48.910842+00:00
# e59157d0-810f-41b2-92c2-436a1658f3eb 2026-05-31 07:06:06.404996+00:00
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3 2026-06-01 12:12:57.823620+00:00
# f9a85d54-1b7f-456a-aa6b-ff9aca727820 2026-05-31 08:22:02.867861+00:00
# 5d47e94b-d860-43ed-b550-b4c8f7f69686 2026-05-30 14:48:29.334024+00:00
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4 2026-06-01 12:00:42.007964+00:00
# 06a90f93-d0e4-45fa-bd98-13678e749829 2026-05-30 12:25:58.577600+00:00
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74 2026-06-02 02:14:59.356492+00:00
# 83ae3cec-79b9-4c3b-966c-376d090b18b1 2026-06-02 10:52:23.976087+00:00
# 1779813177540-23369a30a10fe          2026-05-26 18:38:04.842988+00:00
# 9c80face-f1d4-4cf1-b795-e7522cf68626 2026-05-31 08:10:17.490808+00:00
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c 2026-05-28 20:05:18.304911+00:00
# 1779826329595-9fdf705124d1f8         2026-05-26 20:18:04.514481+00:00
# dc71c15c-9338-4a7b-8f44-b8610848bb2b 2026-06-02 13:10:38.870100+00:00
# 47967fdd-43cd-4f83-b165-2137e5d0863d 2026-06-01 11:58:54.089994+00:00
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471 2026-05-31 07:20:09.578979+00:00
# 8952ae20-5054-4644-9dda-66dc1bf61776 2026-06-01 12:38:50.532335+00:00
# d31bcf45-c5f9-49c2-b279-51f999149198 2026-06-02 10:44:27.126606+00:00
# 102b2e6a-c403-419b-b82e-626a8790dd79 2026-05-31 08:03:20.684387+00:00
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9 2026-05-30 12:00:54.016916+00:00
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd 2026-05-30 18:07:46.548252+00:00
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2 2026-05-30 15:44:15.382145+00:00
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd 2026-06-01 12:02:48.086166+00:00
# 163931f4-ee12-42d5-ad52-c7a11345df25 2026-06-02 15:14:11.657379+00:00
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70 2026-05-28 18:45:00.335577+00:00
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d 2026-05-28 20:15:12.160286+00:00
# a7e24744-5e70-4724-abfb-3a4af25d0531 2026-05-31 13:41:49.942474+00:00
#
#                                       max_difficulty  min_difficulty  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440            10.0             1.0
# 56915d3a-01b4-437c-9166-b6d62b7da9db            10.0             1.0
# aebf0163-b8df-45d1-b834-50d62e09591e            10.0             1.0
# 1779812316142-1873bcf186bbc                      1.0             1.0
# e59157d0-810f-41b2-92c2-436a1658f3eb            10.0             1.0
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3            10.0             1.0
# f9a85d54-1b7f-456a-aa6b-ff9aca727820            10.0             1.0
# 5d47e94b-d860-43ed-b550-b4c8f7f69686            10.0             1.0
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4            10.0             1.0
# 06a90f93-d0e4-45fa-bd98-13678e749829            10.0             1.0
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74            10.0             1.0
# 83ae3cec-79b9-4c3b-966c-376d090b18b1            10.0             1.0
# 1779813177540-23369a30a10fe                     10.0             1.0
# 9c80face-f1d4-4cf1-b795-e7522cf68626            10.0             1.0
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c            10.0             1.0
# 1779826329595-9fdf705124d1f8                    10.0             1.0
# dc71c15c-9338-4a7b-8f44-b8610848bb2b            10.0             1.0
# 47967fdd-43cd-4f83-b165-2137e5d0863d            10.0             1.0
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471            10.0             1.0
# 8952ae20-5054-4644-9dda-66dc1bf61776            10.0             1.0
# d31bcf45-c5f9-49c2-b279-51f999149198            10.0             1.0
# 102b2e6a-c403-419b-b82e-626a8790dd79            10.0             1.0
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9            10.0             1.0
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd            10.0             1.0
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2            10.0             1.0
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd            10.0             1.0
# 163931f4-ee12-42d5-ad52-c7a11345df25            10.0             1.0
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70            10.0             1.0
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d            10.0             1.0
# a7e24744-5e70-4724-abfb-3a4af25d0531            10.0             1.0
#
#                                       max_score  max_height  play_seconds  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440      202.0     30089.0          1370
# 56915d3a-01b4-437c-9166-b6d62b7da9db        2.0     11747.0          1190
# aebf0163-b8df-45d1-b834-50d62e09591e       92.0     21407.0          1040
# 1779812316142-1873bcf186bbc                 0.0         0.0           850
# e59157d0-810f-41b2-92c2-436a1658f3eb        9.0      6425.0           630
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3        0.0      7586.0           620
# f9a85d54-1b7f-456a-aa6b-ff9aca727820       18.0      5129.0           570
# 5d47e94b-d860-43ed-b550-b4c8f7f69686      136.0     20641.0           550
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4       15.0      8697.0           550
# 06a90f93-d0e4-45fa-bd98-13678e749829       74.0     12338.0           540
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74        1.0      1534.0           520
# 83ae3cec-79b9-4c3b-966c-376d090b18b1       29.0      7555.0           440
# 1779813177540-23369a30a10fe               105.0     12801.0           430
# 9c80face-f1d4-4cf1-b795-e7522cf68626       40.0      8178.0           410
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c       55.0      7194.0           360
# 1779826329595-9fdf705124d1f8              109.0     13855.0           350
# dc71c15c-9338-4a7b-8f44-b8610848bb2b       28.0      7353.0           330
# 47967fdd-43cd-4f83-b165-2137e5d0863d        0.0      1219.0           330
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471        3.0       470.0           320
# 8952ae20-5054-4644-9dda-66dc1bf61776       56.0      9883.0           280
# d31bcf45-c5f9-49c2-b279-51f999149198        9.0      4249.0           280
# 102b2e6a-c403-419b-b82e-626a8790dd79       18.0      4070.0           270
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9        9.0      2209.0           270
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd       66.0     10167.0           260
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2       64.0      8324.0           250
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd        0.0       450.0           220
# 163931f4-ee12-42d5-ad52-c7a11345df25        3.0      2311.0           210
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70       14.0      1287.0           200
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d        0.0       561.0           200
# a7e24744-5e70-4724-abfb-3a4af25d0531       21.0      3738.0           180
#
#                                       play_minutes duration_bucket
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440     22.833333            20m+
# 56915d3a-01b4-437c-9166-b6d62b7da9db     19.833333          10–20m
# aebf0163-b8df-45d1-b834-50d62e09591e     17.333333          10–20m
# 1779812316142-1873bcf186bbc              14.166667          10–20m
# e59157d0-810f-41b2-92c2-436a1658f3eb     10.500000          10–20m
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3     10.333333          10–20m
# f9a85d54-1b7f-456a-aa6b-ff9aca727820      9.500000           5–10m
# 5d47e94b-d860-43ed-b550-b4c8f7f69686      9.166667           5–10m
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4      9.166667           5–10m
# 06a90f93-d0e4-45fa-bd98-13678e749829      9.000000           5–10m
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74      8.666667           5–10m
# 83ae3cec-79b9-4c3b-966c-376d090b18b1      7.333333           5–10m
# 1779813177540-23369a30a10fe               7.166667           5–10m
# 9c80face-f1d4-4cf1-b795-e7522cf68626      6.833333           5–10m
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c      6.000000           5–10m
# 1779826329595-9fdf705124d1f8              5.833333           5–10m
# dc71c15c-9338-4a7b-8f44-b8610848bb2b      5.500000           5–10m
# 47967fdd-43cd-4f83-b165-2137e5d0863d      5.500000           5–10m
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471      5.333333           5–10m
# 8952ae20-5054-4644-9dda-66dc1bf61776      4.666667            2–5m
# d31bcf45-c5f9-49c2-b279-51f999149198      4.666667            2–5m
# 102b2e6a-c403-419b-b82e-626a8790dd79      4.500000            2–5m
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9      4.500000            2–5m
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd      4.333333            2–5m
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2      4.166667            2–5m
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd      3.666667            2–5m
# 163931f4-ee12-42d5-ad52-c7a11345df25      3.500000            2–5m
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70      3.333333            2–5m
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d      3.333333            2–5m
# a7e24744-5e70-4724-abfb-3a4af25d0531      3.000000            2–5m
#                  sessions
# duration_bucket
# 10s                     7
# 20–30s                 12
# 40–60s                  8
# 1–2m                   11
# 2–5m                   20
# 5–10m                  13
# 10–20m                  5
# 20m+                    1
# Access tokens: 19
#             rows  sessions                       started_at  \
# token_used
# test_01      290        26 2026-05-24 17:53:16.652248+00:00
# 5656         254         9 2026-05-30 11:56:29.918545+00:00
# 2007         184         5 2026-05-31 09:30:41.864667+00:00
# cupuashoe    173         3 2026-05-27 18:19:23.582343+00:00
# jeannie      131         3 2026-05-31 06:55:46.450566+00:00
# 7676         109         2 2026-05-30 11:56:27.205939+00:00
# 2002          97         4 2026-06-01 11:53:34.163681+00:00
# 2434          84         2 2026-05-30 11:56:33.907756+00:00
# 7278          66         3 2026-05-28 19:59:28.456066+00:00
# 2003          55         1 2026-06-01 11:51:42.028014+00:00
# 2005          53         5 2026-06-01 11:51:18.174667+00:00
# 2013          44         1 2026-06-02 10:45:15.073077+00:00
# 2019          42         2 2026-06-02 13:05:19.079477+00:00
# bea           32         1 2026-05-31 07:14:59.597579+00:00
# 2001          31         4 2026-05-31 09:12:41.066354+00:00
# 2015          21         1 2026-06-02 15:10:52.440414+00:00
# claude        18         1 2026-05-31 07:03:23.630959+00:00
# jaco          18         1 2026-05-31 12:39:26.080810+00:00
# sas_1905      14         3 2026-05-26 20:30:49.335320+00:00
#
#                                    ended_at  max_difficulty  max_score  \
# token_used
# test_01    2026-05-31 07:30:56.913171+00:00            10.0      109.0
# 5656       2026-06-01 12:37:15.481085+00:00            10.0      202.0
# 2007       2026-06-02 15:33:36.883811+00:00            10.0       92.0
# cupuashoe  2026-06-02 04:12:41.250865+00:00            10.0       11.0
# jeannie    2026-05-31 08:10:17.490808+00:00            10.0       40.0
# 7676       2026-05-30 14:48:29.334024+00:00            10.0      136.0
# 2002       2026-06-02 10:39:14.014866+00:00            10.0        0.0
# 2434       2026-05-31 08:22:02.867861+00:00            10.0       18.0
# 7278       2026-05-28 20:17:27.684690+00:00            10.0       55.0
# 2003       2026-06-01 12:00:42.007964+00:00            10.0       15.0
# 2005       2026-06-01 12:46:38.295478+00:00            10.0       12.0
# 2013       2026-06-02 10:52:23.976087+00:00            10.0       29.0
# 2019       2026-06-02 13:20:13.852889+00:00            10.0       37.0
# bea        2026-05-31 07:20:09.578979+00:00            10.0        3.0
# 2001       2026-06-01 12:02:48.086166+00:00            10.0        1.0
# 2015       2026-06-02 15:14:11.657379+00:00            10.0        3.0
# claude     2026-05-31 07:06:13.650056+00:00            10.0        0.0
# jaco       2026-05-31 13:41:49.942474+00:00            10.0       21.0
# sas_1905   2026-05-26 20:33:49.857936+00:00             5.0       18.0
#
#             max_height  play_seconds  play_minutes duration_bucket
# token_used
# test_01        13855.0          2900     48.333333            20m+
# 5656           30089.0          2540     42.333333            20m+
# 2007           21407.0          1840     30.666667            20m+
# cupuashoe      11747.0          1730     28.833333            20m+
# jeannie         8178.0          1310     21.833333            20m+
# 7676           20641.0          1090     18.166667          10–20m
# 2002            7586.0           970     16.166667          10–20m
# 2434            5129.0           840     14.000000          10–20m
# 7278            7194.0           660     11.000000          10–20m
# 2003            8697.0           550      9.166667           5–10m
# 2005            2496.0           530      8.833333           5–10m
# 2013            7555.0           440      7.333333           5–10m
# 2019            7353.0           420      7.000000           5–10m
# bea              470.0           320      5.333333           5–10m
# 2001             450.0           310      5.166667           5–10m
# 2015            2311.0           210      3.500000            2–5m
# claude          1483.0           180      3.000000            2–5m
# jaco            3738.0           180      3.000000            2–5m
# sas_1905        2149.0           140      2.333333            2–5m
#                  access_tokens
# duration_bucket
# 10s                          0
# 20–30s                       0
# 40–60s                       0
# 1–2m                         0
# 2–5m                         4
# 5–10m                        6
# 10–20m                       4
# 20m+                         5
# Difficulty reached by session
#                 sessions
# max_difficulty
# 1.0                    9
# 2.0                    8
# 3.0                    5
# 4.0                    3
# 5.0                    3
# 6.0                    2
# 7.0                    1
# 9.0                    4
# 10.0                  42
# Difficulty reached by access token
#                 access_tokens
# max_difficulty
# 5.0                         1
# 10.0                       18

# %% [markdown]
# ## Data entries by difficulty

# %%
difficulty_counts = (
    windows["difficulty"]
    .value_counts(dropna=False)
    .reindex(range(1, 11), fill_value=0)
    .rename_axis("difficulty")
    .to_frame("rows")
)
difficulty_counts["play_seconds"] = difficulty_counts["rows"] * SECONDS_PER_ROW
difficulty_counts["play_minutes"] = difficulty_counts["play_seconds"] / 60
display(difficulty_counts)

entry_cols = [
    "id", "created_at", "token_used", "session_id", "game_mode", "challenge_label",
    "device_type", "difficulty", "score", "height_climbed", "window_index",
]
entry_cols = [col for col in entry_cols if col in windows]
for difficulty in range(1, 11):
    difficulty_rows = windows[windows["difficulty"].eq(difficulty)].sort_values("created_at")
    print(f"\nDifficulty {difficulty}: {len(difficulty_rows):,} rows")
    display(difficulty_rows[entry_cols].head(20))
# Out:
#             rows  play_seconds  play_minutes
# difficulty
# 1            175          1750     29.166667
# 2             70           700     11.666667
# 3             61           610     10.166667
# 4             54           540      9.000000
# 5             54           540      9.000000
# 6             53           530      8.833333
# 7             52           520      8.666667
# 8             50           500      8.333333
# 9             51           510      8.500000
# 10          1096         10960    182.666667
# Difficulty 1: 175 rows
#                                         id                       created_at  \
# 1234  b7999ed7-3c4b-431a-85ef-0c0408c08e43 2026-05-24 17:53:16.652248+00:00
# 141   17030568-5d10-4eb5-af90-228fb2978057 2026-05-24 17:58:21.020781+00:00
# 1035  98c11447-e855-4070-9bf3-5c15dd5a8331 2026-05-25 21:11:40.224958+00:00
# 324   320c6dde-fa93-45df-9892-b3b2e95d1b15 2026-05-25 21:15:11.395187+00:00
# 597   5762277e-a640-45f4-bc9d-5ed748eedc69 2026-05-26 16:15:52.935158+00:00
# 152   18999196-bfee-4b3b-aa7c-255a461fe096 2026-05-26 16:18:49.500311+00:00
# 115   13463d08-66f3-4476-b8eb-9b736efb1dd4 2026-05-26 16:18:59.098997+00:00
# 187   1d24b4be-bdb2-4b0c-b1c0-f852e27093f7 2026-05-26 16:19:09.098536+00:00
# 957   8d30d703-bb25-4c2f-8be8-8ef74d97acb8 2026-05-26 16:19:19.203879+00:00
# 1448  dbe678e9-efc8-4080-90e3-89c46b08ae62 2026-05-26 16:19:29.105842+00:00
# 1564  ebf28eed-032c-451d-886a-2e6c66bcec63 2026-05-26 16:19:39.120708+00:00
# 543   50a060a7-b620-46a9-9d80-27c071885679 2026-05-26 16:19:49.103706+00:00
# 1358  cc276aaa-ed0c-47a4-ad0f-66e7f268b6a1 2026-05-26 16:19:59.096205+00:00
# 761   70aa1f82-e188-4578-894b-06152284acfa 2026-05-26 16:20:09.097511+00:00
# 1107  a370eab8-ffe8-4b62-83c2-dd351ab93d7e 2026-05-26 16:20:19.102639+00:00
# 1192  b14cfe17-1bb5-454b-b3d3-dca0c00294ef 2026-05-26 16:20:29.089252+00:00
# 344   34bf2962-f2f0-441c-9c15-29394440eebf 2026-05-26 16:20:39.115082+00:00
# 553   52225fe5-6e84-45f8-a5c8-b1f584bcfc52 2026-05-26 16:20:49.176030+00:00
# 1003  942c7c39-1c72-4876-94e0-0ff4c8255642 2026-05-26 16:20:59.218484+00:00
# 867   7fa66022-2c4a-4567-a1c8-ce70de077abb 2026-05-26 16:21:09.093486+00:00
#
#      token_used                            session_id game_mode  \
# 1234    test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e     train
# 141     test_01  2c14c585-0adb-4fff-8156-f9711e95008f     train
# 1035    test_01          1779743473482-74c1b016dcbe18   flow-ML
# 324     test_01  d2debd5d-49dd-4cb5-8404-bf96c7e57512   flow-ML
# 597     test_01          1779812135156-0604b0bb3d4448   flow-ML
# 152     test_01           1779812316142-1873bcf186bbc   flow-ML
# 115     test_01           1779812316142-1873bcf186bbc   flow-ML
# 187     test_01           1779812316142-1873bcf186bbc   flow-ML
# 957     test_01           1779812316142-1873bcf186bbc   flow-ML
# 1448    test_01           1779812316142-1873bcf186bbc   flow-ML
# 1564    test_01           1779812316142-1873bcf186bbc   flow-ML
# 543     test_01           1779812316142-1873bcf186bbc   flow-ML
# 1358    test_01           1779812316142-1873bcf186bbc   flow-ML
# 761     test_01           1779812316142-1873bcf186bbc   flow-ML
# 1107    test_01           1779812316142-1873bcf186bbc   flow-ML
# 1192    test_01           1779812316142-1873bcf186bbc   flow-ML
# 344     test_01           1779812316142-1873bcf186bbc   flow-ML
# 553     test_01           1779812316142-1873bcf186bbc   flow-ML
# 1003    test_01           1779812316142-1873bcf186bbc   flow-ML
# 867     test_01           1779812316142-1873bcf186bbc   flow-ML
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 1234          under_challenged     desktop         1.0    4.0           456.0
# 141           under_challenged     desktop         1.0    9.0           908.0
# 1035          under_challenged     desktop         1.0    5.0           418.0
# 324           under_challenged     desktop         1.0    6.0           606.0
# 597           under_challenged     desktop         1.0    2.0           178.0
# 152   appropriately_challenged     desktop         1.0    0.0             0.0
# 115            over_challenged     desktop         1.0    0.0             0.0
# 187            over_challenged     desktop         1.0    0.0             0.0
# 957            over_challenged     desktop         1.0    0.0             0.0
# 1448           over_challenged     desktop         1.0    0.0             0.0
# 1564           over_challenged     desktop         1.0    0.0             0.0
# 543            over_challenged     desktop         1.0    0.0             0.0
# 1358           over_challenged     desktop         1.0    0.0             0.0
# 761            over_challenged     desktop         1.0    0.0             0.0
# 1107           over_challenged     desktop         1.0    0.0             0.0
# 1192           over_challenged     desktop         1.0    0.0             0.0
# 344            over_challenged     desktop         1.0    0.0             0.0
# 553            over_challenged     desktop         1.0    0.0             0.0
# 1003           over_challenged     desktop         1.0    0.0             0.0
# 867            over_challenged     desktop         1.0    0.0             0.0
#
#       window_index
# 1234           0.0
# 141            0.0
# 1035           0.0
# 324            0.0
# 597            0.0
# 152            0.0
# 115            1.0
# 187            2.0
# 957            3.0
# 1448           4.0
# 1564           5.0
# 543            6.0
# 1358           7.0
# 761            8.0
# 1107           9.0
# 1192          10.0
# 344           11.0
# 553           12.0
# 1003          13.0
# 867           14.0
# Difficulty 2: 70 rows
#                                         id                       created_at  \
# 1275  be4c531f-5391-4251-a242-5f8f91c772fd 2026-05-24 17:54:10.747313+00:00
# 348   3524a4c9-54a6-4d00-9b21-1211f8d05ec6 2026-05-24 17:58:31.006891+00:00
# 287   2c1b8c7d-ea5e-4890-ab82-f6b8e5097367 2026-05-25 21:11:50.170097+00:00
# 1714  ffaa6c7a-5dc5-4982-988d-b871930d30aa 2026-05-25 21:15:21.370323+00:00
# 1386  d070d438-cc0f-4640-887c-492b37d04dc5 2026-05-26 16:33:30.439909+00:00
# 395   3c60bb89-3dee-40cb-b811-bdda88e3cc12 2026-05-26 18:35:44.785547+00:00
# 1567  ec6706fe-adeb-4a88-b907-ba0f54e4a53c 2026-05-26 18:38:59.727549+00:00
# 1127  a710506d-43fa-4f10-a584-96e594507f18 2026-05-26 20:12:44.606020+00:00
# 174   1b5c8d84-c0f4-4b62-bc6e-09a328641599 2026-05-26 20:30:59.216906+00:00
# 186   1d12d276-7cb8-4df3-8d86-0ebc8ff7af47 2026-05-26 20:32:26.166518+00:00
# 1124  a5f2e7a7-b710-43b6-9284-34ed6ddfe9c1 2026-05-26 20:32:36.141616+00:00
# 1602  f11e69e4-2537-400d-9a91-ee782dcf0e8e 2026-05-26 20:33:49.857936+00:00
# 1585  ef32bc43-be4e-49fa-ae85-6c951f1111c7 2026-05-27 18:00:21.113236+00:00
# 1114  a417f868-78b5-4489-aefc-cd90cacdb9bb 2026-05-27 18:12:49.930438+00:00
# 1470  dfe17449-be44-4d14-b374-455ea822d18b 2026-05-27 18:19:33.484389+00:00
# 1670  f936f1eb-f706-496e-8f17-0507e70490bb 2026-05-27 18:24:33.020947+00:00
# 299   2d8f1d8c-ea12-409f-9d05-494ec184f128 2026-05-27 18:46:21.235162+00:00
# 1621  f400d5fe-c55c-4438-aa44-7e4edf952f4e 2026-05-28 18:15:06.207457+00:00
# 1259  bb0cc670-393e-43dd-935e-cbeff1de4656 2026-05-28 18:22:33.566914+00:00
# 860   7ef89715-8628-4a7e-b701-7351d3f72e21 2026-05-28 18:23:21.000999+00:00
#
#      token_used                            session_id       game_mode  \
# 1275    test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 348     test_01  2c14c585-0adb-4fff-8156-f9711e95008f           train
# 287     test_01          1779743473482-74c1b016dcbe18         flow-ML
# 1714    test_01  d2debd5d-49dd-4cb5-8404-bf96c7e57512         flow-ML
# 1386    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 395     test_01           1779813177540-23369a30a10fe         flow-ML
# 1567    test_01          1779820714773-81a086f8c86fb8  flow-heuristic
# 1127    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 174    sas_1905  8319f0b3-933e-49c1-921d-928125864b2d         flow-ML
# 186    sas_1905  4e234513-5319-42a3-ab6d-235c53c2c92f  flow-heuristic
# 1124   sas_1905  4e234513-5319-42a3-ab6d-235c53c2c92f  flow-heuristic
# 1602   sas_1905  9e345b77-16ea-448c-8882-7e4b7eb55cc8         flow-ML
# 1585    test_01           1779904796201-480a90ed40453           train
# 1114    test_01           1779905546767-8d568fce62b02           train
# 1470  cupuashoe  65c1a107-e3b2-4943-a242-a24aa624f42d           train
# 1670    test_01           1779906249666-7e75a437c1d4c           train
# 299     test_01          1779907556493-3485464a5ca978           train
# 1621    test_01          1779992056725-f50d8c1a321748           train
# 1259    test_01          1779992500891-6b9658b950b718           train
# 860     test_01          1779992500891-6b9658b950b718           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 1275          under_challenged     desktop         2.0   11.0          1017.0
# 348   appropriately_challenged     desktop         2.0   16.0          1631.0
# 287           under_challenged     desktop         2.0   12.0           955.0
# 1714          under_challenged     desktop         2.0    7.0           915.0
# 1386          under_challenged     desktop         2.0   12.0          1294.0
# 395           under_challenged     desktop         2.0   11.0          1178.0
# 1567  appropriately_challenged     desktop         2.0   10.0           953.0
# 1127          under_challenged     desktop         2.0   11.0          1154.0
# 174           under_challenged      mobile         2.0    5.0           552.0
# 186   appropriately_challenged      mobile         2.0    3.0           457.0
# 1124          under_challenged      mobile         2.0    8.0           995.0
# 1602          under_challenged      mobile         2.0    6.0           641.0
# 1585          under_challenged     desktop         2.0   16.0          1598.0
# 1114          under_challenged     desktop         2.0    7.0           922.0
# 1470          under_challenged      mobile         2.0   11.0           954.0
# 1670           over_challenged     desktop         2.0    4.0           693.0
# 299           under_challenged     desktop         2.0    9.0          1151.0
# 1621  appropriately_challenged     desktop         2.0    7.0           886.0
# 1259          under_challenged     desktop         2.0   12.0          1306.0
# 860   appropriately_challenged     desktop         2.0    7.0          1145.0
#
#       window_index
# 1275           1.0
# 348            1.0
# 287            1.0
# 1714           1.0
# 1386           1.0
# 395            1.0
# 1567           1.0
# 1127           1.0
# 174            1.0
# 186            1.0
# 1124           2.0
# 1602           1.0
# 1585           1.0
# 1114           1.0
# 1470           1.0
# 1670           1.0
# 299            1.0
# 1621           1.0
# 1259           1.0
# 860            1.0
# Difficulty 3: 61 rows
#                                         id                       created_at  \
# 1215  b5b13f95-5983-48d7-b0ef-86c8f6e17632 2026-05-24 17:58:40.999873+00:00
# 336   337e68ca-4872-4143-8022-165f69d873ac 2026-05-25 21:12:00.182339+00:00
# 28    05a02ca8-6639-49a0-b5b3-4d0dab92bf87 2026-05-25 21:15:31.364558+00:00
# 1573  ed01c884-f5e7-4efa-9033-36f8cffebb5e 2026-05-26 16:33:40.457119+00:00
# 872   80776fff-2069-45d9-ad9a-d8a71c238f4c 2026-05-26 16:33:50.473278+00:00
# 1415  d58de345-ef2e-4b7d-861c-e13218e670cc 2026-05-26 18:35:54.793754+00:00
# 443   43fb1c7f-45d8-43e4-95e5-1a5b3a3803c6 2026-05-26 20:12:54.521815+00:00
# 669   61f9afef-a413-4637-ac4f-a55ab347a7ee 2026-05-26 20:31:09.249292+00:00
# 874   80a91f72-60f4-4b4c-83f9-600ec8e936ef 2026-05-26 20:31:19.224521+00:00
# 429   41cff181-43f2-4853-89fb-b2ecd7513ff2 2026-05-26 20:31:29.344324+00:00
# 641   5de6feea-6989-49f6-b0e3-33fbdcc89086 2026-05-26 20:32:46.174961+00:00
# 1642  f59695d4-3c55-4856-9645-96b5ea92f985 2026-05-26 20:32:56.174350+00:00
# 666   61a4fb42-d551-407a-8c56-186c602a8a9b 2026-05-27 18:00:31.121918+00:00
# 1256  baa67a64-82c2-4a74-b501-824fcd1639b3 2026-05-27 18:12:59.923024+00:00
# 318   312e7ebc-6925-4b57-ae69-6460159056ff 2026-05-27 18:46:31.220840+00:00
# 462   45a09d25-baed-4ca2-ad3d-ad0ea6016d99 2026-05-28 18:15:16.180487+00:00
# 1504  e415c7a4-ece0-4add-b9a4-df6e10ad408b 2026-05-28 18:35:53.571118+00:00
# 1560  eb528e13-c2d1-4d5f-99a5-12a731fd86c0 2026-05-28 18:42:10.886357+00:00
# 1013  9543b323-4dec-447b-8d3a-ce39ea8134d5 2026-05-28 18:45:32.967954+00:00
# 1266  bc505b27-49cb-47b7-b0b1-c73bee54ece3 2026-05-28 18:47:08.473466+00:00
#
#      token_used                            session_id       game_mode  \
# 1215    test_01  2c14c585-0adb-4fff-8156-f9711e95008f           train
# 336     test_01          1779743473482-74c1b016dcbe18         flow-ML
# 28      test_01  d2debd5d-49dd-4cb5-8404-bf96c7e57512         flow-ML
# 1573    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 872     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 1415    test_01           1779813177540-23369a30a10fe         flow-ML
# 443     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 669    sas_1905  8319f0b3-933e-49c1-921d-928125864b2d         flow-ML
# 874    sas_1905  8319f0b3-933e-49c1-921d-928125864b2d         flow-ML
# 429    sas_1905  8319f0b3-933e-49c1-921d-928125864b2d         flow-ML
# 641    sas_1905  4e234513-5319-42a3-ab6d-235c53c2c92f  flow-heuristic
# 1642   sas_1905  4e234513-5319-42a3-ab6d-235c53c2c92f  flow-heuristic
# 666     test_01           1779904796201-480a90ed40453           train
# 1256    test_01           1779905546767-8d568fce62b02           train
# 318     test_01          1779907556493-3485464a5ca978           train
# 462     test_01          1779992056725-f50d8c1a321748           train
# 1504    test_01          1779993323338-b4bbd02ebc3268           train
# 1560    test_01  8a8a6b73-c1d6-4819-9ae3-4b0038131b70           train
# 1013    test_01  c06bc4ff-7384-48f3-9a0b-703b27d03933           train
# 1266    test_01  0779b210-90c5-4497-9675-0b08515d83ad           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 1215          under_challenged     desktop         3.0   23.0          2218.0
# 336           under_challenged     desktop         3.0   17.0          1312.0
# 28            under_challenged     desktop         3.0   12.0          1270.0
# 1573  appropriately_challenged     desktop         3.0   19.0          2144.0
# 872           under_challenged     desktop         3.0   24.0          2637.0
# 1415          under_challenged     desktop         3.0   16.0          1458.0
# 443           under_challenged     desktop         3.0   14.0          1358.0
# 669   appropriately_challenged      mobile         3.0    6.0           656.0
# 874   appropriately_challenged      mobile         3.0    7.0           855.0
# 429   appropriately_challenged      mobile         3.0   10.0          1134.0
# 641   appropriately_challenged      mobile         3.0    8.0          1104.0
# 1642          under_challenged      mobile         3.0   12.0          1541.0
# 666           under_challenged     desktop         3.0   20.0          1799.0
# 1256          under_challenged     desktop         3.0   11.0          1344.0
# 318           under_challenged     desktop         3.0   17.0          1930.0
# 462            over_challenged     desktop         3.0    8.0           986.0
# 1504          under_challenged     desktop         3.0   18.0          1963.0
# 1560          under_challenged      mobile         3.0    9.0           797.0
# 1013  appropriately_challenged      mobile         3.0    8.0           677.0
# 1266          under_challenged      mobile         3.0   11.0          1065.0
#
#       window_index
# 1215           2.0
# 336            2.0
# 28             2.0
# 1573           2.0
# 872            3.0
# 1415           2.0
# 443            2.0
# 669            2.0
# 874            3.0
# 429            4.0
# 641            3.0
# 1642           4.0
# 666            2.0
# 1256           2.0
# 318            2.0
# 462            2.0
# 1504           2.0
# 1560           2.0
# 1013           2.0
# 1266           2.0
# Difficulty 4: 54 rows
#                                         id                       created_at  \
# 1645  f5e3cfc5-1d52-4ed2-b65b-a7e7c717f56a 2026-05-25 21:12:10.371766+00:00
# 293   2cd74d57-aa10-4cb8-a31a-f271861ab9de 2026-05-25 21:15:41.353604+00:00
# 88    0f30d56f-8c0b-4402-9e0f-b16cd7ffc028 2026-05-26 16:34:00.513328+00:00
# 985   912caf91-6c36-4922-89c2-58df1b6cce2a 2026-05-26 18:36:04.790538+00:00
# 283   2bd1b6d7-2eb6-410a-bec6-a6dd9d37ab38 2026-05-26 20:13:04.509317+00:00
# 725   6c1e4732-6554-434a-9f3e-d5bf54e6983a 2026-05-26 20:13:14.519688+00:00
# 659   608a92f3-6323-4f4a-8eb6-7fc535f695e7 2026-05-26 20:13:24.508049+00:00
# 718   6b4d5ed3-2911-4beb-a2ba-0b17a5bc0936 2026-05-26 20:33:06.342065+00:00
# 1068  9e76c8b9-e83a-4ab2-8d5c-c4069206117e 2026-05-27 18:13:09.981541+00:00
# 1182  b010e4cb-92b5-45cc-b612-619106f19335 2026-05-27 18:46:41.204253+00:00
# 248   26d26f57-a329-4231-96ce-c5c3ce656987 2026-05-28 18:15:26.171705+00:00
# 1098  a217ae89-437b-4808-839b-1bfeb46fab0f 2026-05-28 18:42:20.340573+00:00
# 247   2692337b-d345-4578-8caf-e35b57d5f857 2026-05-28 18:45:42.981135+00:00
# 713   6a5d2003-40e0-4416-8d75-31cc9caa07d8 2026-05-28 18:47:18.477942+00:00
# 1643  f5a535b4-aa5a-4ae9-bc7d-34524055c3a8 2026-05-28 19:59:58.295759+00:00
# 1225  b69f4484-cc3f-499d-9b71-35c32f85aecd 2026-05-28 20:12:31.926194+00:00
# 449   447998f9-c261-4857-bafa-cb5e8d7d26f7 2026-05-28 20:16:27.694916+00:00
# 1491  e25d9baa-c478-49d8-a638-13e42b488105 2026-05-30 11:33:17.015852+00:00
# 1145  aa30fda9-0f88-458b-be62-c2188e6824c6 2026-05-30 11:56:57.187858+00:00
# 1406  d3af8534-8c5b-403b-bcc2-9dbf3b8b4bb5 2026-05-30 11:56:59.884099+00:00
#
#      token_used                            session_id       game_mode  \
# 1645    test_01          1779743473482-74c1b016dcbe18         flow-ML
# 293     test_01  d2debd5d-49dd-4cb5-8404-bf96c7e57512         flow-ML
# 88      test_01           1779813177540-23369a30a10fe  flow-heuristic
# 985     test_01           1779813177540-23369a30a10fe         flow-ML
# 283     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 725     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 659     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 718    sas_1905  4e234513-5319-42a3-ab6d-235c53c2c92f  flow-heuristic
# 1068    test_01           1779905546767-8d568fce62b02           train
# 1182    test_01          1779907556493-3485464a5ca978           train
# 248     test_01          1779992056725-f50d8c1a321748           train
# 1098    test_01  8a8a6b73-c1d6-4819-9ae3-4b0038131b70           train
# 247     test_01  c06bc4ff-7384-48f3-9a0b-703b27d03933           train
# 713     test_01  0779b210-90c5-4497-9675-0b08515d83ad           train
# 1643       7278  15df3483-1d20-44c8-9ed9-7a8a49cfcc1c           train
# 1225       7278  6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d           train
# 449        7278  d30dc88d-9b08-419b-b5a2-ae5ccfc78557           train
# 1491    test_01  28e8dff4-1f9f-4bc8-a790-f9cf92f20764           train
# 1145       7676  06a90f93-d0e4-45fa-bd98-13678e749829           train
# 1406       5656  4fb7ae84-6ccd-48fd-9571-d65683a9e440           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 1645          under_challenged     desktop         4.0   23.0          1849.0
# 293           under_challenged     desktop         4.0   15.0          1490.0
# 88            under_challenged     desktop         4.0   30.0          3151.0
# 985           under_challenged     desktop         4.0   20.0          1794.0
# 283   appropriately_challenged     desktop         4.0   14.0          1358.0
# 725   appropriately_challenged     desktop         4.0   16.0          1514.0
# 659           under_challenged     desktop         4.0   19.0          1900.0
# 718           under_challenged      mobile         4.0   15.0          1872.0
# 1068          under_challenged     desktop         4.0   17.0          1785.0
# 1182          under_challenged     desktop         4.0   22.0          2364.0
# 248           under_challenged     desktop         4.0   13.0          1520.0
# 1098  appropriately_challenged      mobile         4.0    9.0           797.0
# 247   appropriately_challenged      mobile         4.0    8.0           677.0
# 713           under_challenged      mobile         4.0   14.0          1311.0
# 1643  appropriately_challenged      mobile         4.0   15.0          1477.0
# 1225  appropriately_challenged      mobile         4.0   -1.0           431.0
# 449           under_challenged      mobile         4.0   12.0          1727.0
# 1491           over_challenged     desktop         4.0   10.0          1271.0
# 1145  appropriately_challenged      mobile         4.0    7.0          1142.0
# 1406  appropriately_challenged      mobile         4.0   -3.0           341.0
#
#       window_index
# 1645           3.0
# 293            3.0
# 88             4.0
# 985            3.0
# 283            3.0
# 725            4.0
# 659            5.0
# 718            5.0
# 1068           3.0
# 1182           3.0
# 248            3.0
# 1098           3.0
# 247            3.0
# 713            3.0
# 1643           3.0
# 1225           3.0
# 449            3.0
# 1491           3.0
# 1145           3.0
# 1406           3.0
# Difficulty 5: 54 rows
#                                         id                       created_at  \
# 1558  eb390e3d-a7f9-41ed-8d0a-c1ffbd6b61ee 2026-05-25 21:12:20.223669+00:00
# 829   7b156af9-d810-41d1-a6c1-503b70ec3550 2026-05-25 21:12:30.178336+00:00
# 1449  dbea9624-5014-4de5-90c5-2b41246cbe55 2026-05-26 16:34:10.469144+00:00
# 1187  b073e984-89cf-4df3-8425-a5c99888a734 2026-05-26 16:36:10.517678+00:00
# 934   88b0c762-a8b2-472f-b04b-2eb818fd4880 2026-05-26 16:36:30.833942+00:00
# 29    05c1f37e-d19d-4d6c-bd02-3f0a9f2082c8 2026-05-26 16:36:50.531245+00:00
# 1078  9fd35409-14da-4e42-a752-80e095676bb4 2026-05-26 18:36:14.837622+00:00
# 1435  d9179cfa-6c41-4be3-8cef-cd86cb20e0ce 2026-05-26 18:36:24.800406+00:00
# 601   57d1be59-cc39-4d46-89f9-d016e3a11355 2026-05-26 20:13:34.504341+00:00
# 1689  fb71a2e8-a33e-43b1-9f08-b12809dcc6c8 2026-05-26 20:33:16.162857+00:00
# 421   40c8f5ba-df15-45ac-986d-a4fdccd6378c 2026-05-27 18:13:20.049643+00:00
# 333   333074ce-d1cd-4cdf-b2e5-2ed72e40f249 2026-05-28 18:42:30.324670+00:00
# 353   3553d580-3768-4c62-80c9-1e11c6ad5ce6 2026-05-28 18:45:52.968168+00:00
# 525   4e20d3e6-6318-4dfa-afd6-2fdd6429b37d 2026-05-28 18:47:28.494599+00:00
# 864   7f78fde9-29f3-424b-bdf4-05492f8c12eb 2026-05-28 20:00:08.354473+00:00
# 1550  e9bcc0bc-da3f-4fbc-86d8-d0450c11f6d5 2026-05-28 20:12:41.909583+00:00
# 1146  aa41fe0b-3ef6-46df-a0c9-9b80126e215f 2026-05-28 20:16:37.684343+00:00
# 55    0ac252f8-8cd6-4c44-bab9-468ad70f5ae5 2026-05-30 11:57:07.204072+00:00
# 119   1396115f-9e18-4de1-95e3-df57206524e6 2026-05-30 11:57:09.902056+00:00
# 1298  c2320fb4-28f2-4bf9-8783-6da9691f2c8a 2026-05-30 11:57:13.847911+00:00
#
#      token_used                            session_id       game_mode  \
# 1558    test_01          1779743473482-74c1b016dcbe18         flow-ML
# 829     test_01          1779743473482-74c1b016dcbe18         flow-ML
# 1449    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 1187    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 934     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 29      test_01           1779813177540-23369a30a10fe  flow-heuristic
# 1078    test_01           1779813177540-23369a30a10fe         flow-ML
# 1435    test_01           1779813177540-23369a30a10fe         flow-ML
# 601     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 1689   sas_1905  4e234513-5319-42a3-ab6d-235c53c2c92f  flow-heuristic
# 421     test_01           1779905546767-8d568fce62b02           train
# 333     test_01  8a8a6b73-c1d6-4819-9ae3-4b0038131b70           train
# 353     test_01  c06bc4ff-7384-48f3-9a0b-703b27d03933           train
# 525     test_01  0779b210-90c5-4497-9675-0b08515d83ad           train
# 864        7278  15df3483-1d20-44c8-9ed9-7a8a49cfcc1c           train
# 1550       7278  6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d           train
# 1146       7278  d30dc88d-9b08-419b-b5a2-ae5ccfc78557           train
# 55         7676  06a90f93-d0e4-45fa-bd98-13678e749829           train
# 119        5656  4fb7ae84-6ccd-48fd-9571-d65683a9e440           train
# 1298       2434  26ca1a34-1ca5-4c48-80ee-7f040167b0d9           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 1558  appropriately_challenged     desktop         5.0   23.0          1849.0
# 829           under_challenged     desktop         5.0   31.0          2447.0
# 1449          under_challenged     desktop         5.0   38.0          4052.0
# 1187          under_challenged     desktop         5.0   71.0          8769.0
# 934           under_challenged     desktop         5.0   82.0         10018.0
# 29            under_challenged     desktop         5.0   93.0         11501.0
# 1078  appropriately_challenged     desktop         5.0   26.0          2158.0
# 1435          under_challenged     desktop         5.0   34.0          2950.0
# 601           under_challenged     desktop         5.0   25.0          2454.0
# 1689          under_challenged      mobile         5.0   18.0          2149.0
# 421   appropriately_challenged     desktop         5.0   18.0          1900.0
# 333   appropriately_challenged      mobile         5.0    9.0           797.0
# 353   appropriately_challenged      mobile         5.0    8.0           677.0
# 525           under_challenged      mobile         5.0   19.0          1988.0
# 864           under_challenged      mobile         5.0   22.0          2156.0
# 1550  appropriately_challenged      mobile         5.0   -1.0           431.0
# 1146  appropriately_challenged      mobile         5.0   12.0          1727.0
# 55            under_challenged      mobile         5.0   14.0          1849.0
# 119           under_challenged      mobile         5.0   -1.0           549.0
# 1298  appropriately_challenged      mobile         5.0    8.0          1189.0
#
#       window_index
# 1558           4.0
# 829            5.0
# 1449           5.0
# 1187          17.0
# 934           19.0
# 29            21.0
# 1078           4.0
# 1435           5.0
# 601            6.0
# 1689           6.0
# 421            4.0
# 333            4.0
# 353            4.0
# 525            4.0
# 864            4.0
# 1550           4.0
# 1146           4.0
# 55             4.0
# 119            4.0
# 1298           4.0
# Difficulty 6: 53 rows
#                                         id                       created_at  \
# 1105  a2d6ede3-7d7f-444a-b914-5019bd7fd521 2026-05-25 21:12:40.175693+00:00
# 741   6d38eeb6-6ec1-417d-9682-7774325b8b34 2026-05-26 16:34:20.445257+00:00
# 464   460e4304-2a61-4a57-b4ff-c4a07c399af7 2026-05-26 16:34:30.547914+00:00
# 966   8e339c13-1669-4ab5-828b-187d0b5788ec 2026-05-26 16:35:40.466279+00:00
# 485   48ebe67f-2d2f-446b-8ace-aec1d3b56ee7 2026-05-26 16:36:00.464958+00:00
# 1459  de4b532a-f930-4caf-880b-da65b81d7573 2026-05-26 16:36:20.615390+00:00
# 1281  bf1787d3-b797-47c6-8639-0d287f2bb1f8 2026-05-26 16:36:40.577778+00:00
# 202   1feac6af-5665-4176-afd7-315b5b089cac 2026-05-26 16:37:00.463810+00:00
# 622   5aae3f63-72ad-4f8c-83f8-d872a08cb84f 2026-05-26 16:37:10.484809+00:00
# 745   6d9d1b37-a4a5-4cc9-9ba0-ed667b758327 2026-05-26 18:36:34.791858+00:00
# 491   49a5036e-c5a6-40f8-892d-0d53bc4d9971 2026-05-26 20:13:44.504207+00:00
# 852   7df18395-b1a6-48de-a1b5-7dc9a2f05b15 2026-05-28 18:42:40.337747+00:00
# 1575  ed3beb79-3bb6-4769-a59f-9930dc6ef9ab 2026-05-28 18:46:02.996180+00:00
# 463   45d0baa9-4d94-4841-b4b4-db0b76cbe6b2 2026-05-28 18:47:38.536090+00:00
# 1445  dafb53ba-a6f8-46c2-9cd4-8ea8a17fc6e2 2026-05-28 20:00:18.289256+00:00
# 304   2e9e50bc-1da8-4ace-a028-1037c7a5e1ba 2026-05-28 20:12:51.952078+00:00
# 583   55904ab2-f1f6-4aab-bc5a-2b222ec2fb32 2026-05-28 20:16:47.692336+00:00
# 493   4a303904-bffe-41ef-bff8-7978a9dee7cd 2026-05-30 11:57:17.157787+00:00
# 430   41fa5758-74a5-4785-8f1c-f1389b45ad8a 2026-05-30 11:57:19.885257+00:00
# 1622  f4249c59-3fed-47cc-a615-56903d86bd96 2026-05-30 11:57:23.820414+00:00
#
#      token_used                            session_id       game_mode  \
# 1105    test_01          1779743473482-74c1b016dcbe18         flow-ML
# 741     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 464     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 966     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 485     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 1459    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 1281    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 202     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 622     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 745     test_01           1779813177540-23369a30a10fe         flow-ML
# 491     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 852     test_01  8a8a6b73-c1d6-4819-9ae3-4b0038131b70           train
# 1575    test_01  c06bc4ff-7384-48f3-9a0b-703b27d03933           train
# 463     test_01  0779b210-90c5-4497-9675-0b08515d83ad           train
# 1445       7278  15df3483-1d20-44c8-9ed9-7a8a49cfcc1c           train
# 304        7278  6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d           train
# 583        7278  d30dc88d-9b08-419b-b5a2-ae5ccfc78557           train
# 493        7676  06a90f93-d0e4-45fa-bd98-13678e749829           train
# 430        5656  4fb7ae84-6ccd-48fd-9571-d65683a9e440           train
# 1622       2434  26ca1a34-1ca5-4c48-80ee-7f040167b0d9           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 1105          under_challenged     desktop         6.0   36.0          2881.0
# 741   appropriately_challenged     desktop         6.0   44.0          4682.0
# 464           under_challenged     desktop         6.0   50.0          5312.0
# 966           under_challenged     desktop         6.0   71.0          8335.0
# 485            over_challenged     desktop         6.0   68.0          8452.0
# 1459           over_challenged     desktop         6.0   72.0          9121.0
# 1281           over_challenged     desktop         6.0   87.0         10802.0
# 202   appropriately_challenged     desktop         6.0   97.0         11897.0
# 622           under_challenged     desktop         6.0  101.0         12508.0
# 745           under_challenged     desktop         6.0   39.0          3474.0
# 491           under_challenged     desktop         6.0   31.0          3105.0
# 852   appropriately_challenged      mobile         6.0    9.0           797.0
# 1575  appropriately_challenged      mobile         6.0    8.0           677.0
# 463           under_challenged      mobile         6.0   24.0          2463.0
# 1445          under_challenged      mobile         6.0   28.0          2658.0
# 304   appropriately_challenged      mobile         6.0   -1.0           431.0
# 583   appropriately_challenged      mobile         6.0   12.0          1727.0
# 493           under_challenged      mobile         6.0   18.0          2313.0
# 430           under_challenged      mobile         6.0    1.0           996.0
# 1622           over_challenged      mobile         6.0    6.0          1189.0
#
#       window_index
# 1105           6.0
# 741            6.0
# 464            7.0
# 966           14.0
# 485           16.0
# 1459          18.0
# 1281          20.0
# 202           22.0
# 622           23.0
# 745            6.0
# 491            7.0
# 852            5.0
# 1575           5.0
# 463            5.0
# 1445           5.0
# 304            5.0
# 583            5.0
# 493            5.0
# 430            5.0
# 1622           5.0
# Difficulty 7: 52 rows
#                                         id                       created_at  \
# 2     010b5794-b00e-4689-87b9-592636ce6db5 2026-05-24 17:54:20.479066+00:00
# 1652  f6b2d96c-6532-4711-8dae-db51fe25c0c2 2026-05-26 16:34:40.456596+00:00
# 497   4abf4bb9-5acc-4100-9781-08b052b8a0da 2026-05-26 16:35:00.624182+00:00
# 612   596ee532-82db-4326-a614-3c718dfd46dd 2026-05-26 16:35:30.553188+00:00
# 162   19e04706-221a-4ed1-8f99-5fc876b8bd1b 2026-05-26 16:35:50.466394+00:00
# 133   1613bd73-7e0f-405b-8b9c-36f9c35b3312 2026-05-26 16:37:20.454744+00:00
# 1254  ba658f24-ddd6-44c5-9e5b-c1d7d5a64ac8 2026-05-26 16:37:30.471837+00:00
# 1675  f9aaa17b-f456-4489-ab40-fbcb4030a4be 2026-05-26 16:37:40.468609+00:00
# 809   77e4cc03-16f2-4859-a2a1-7fc1a99c70e4 2026-05-26 18:36:44.794777+00:00
# 1295  c1716775-ec26-45e7-bbe3-53271a12915a 2026-05-26 20:13:54.505246+00:00
# 166   1a2e2754-23d2-4da3-b5ea-ba4eddb866f4 2026-05-28 18:42:50.332591+00:00
# 1     00e009d2-a72c-4902-aed9-e852a92d7e4a 2026-05-28 18:46:13.139322+00:00
# 656   5fcc2b6b-1182-4b98-b4c5-c488299ae109 2026-05-28 20:00:28.296780+00:00
# 570   546a7e89-f069-4e0d-8142-80666c2843d3 2026-05-28 20:13:01.914106+00:00
# 1202  b2bb5a5e-c53a-453e-89d2-6058ccbe430c 2026-05-28 20:16:57.702501+00:00
# 579   5539a6cf-0e53-4ba8-a6a0-5c6c30444842 2026-05-30 11:57:27.192345+00:00
# 1577  ed8a7ed9-8d89-4f5c-9bc1-31a0009010db 2026-05-30 11:57:29.921603+00:00
# 580   5562f142-e950-4c92-bf87-5bcbf11f28ed 2026-05-30 11:57:33.839892+00:00
# 1104  a2be12c9-1041-446e-a8ba-1bd85a580a7b 2026-05-30 12:02:06.466795+00:00
# 1106  a2fe7033-dc42-46c7-828d-8eecc9864c3a 2026-05-30 14:40:11.112215+00:00
#
#      token_used                            session_id       game_mode  \
# 2       test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 1652    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 497     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 612     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 162     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 133     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 1254    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 1675    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 809     test_01           1779813177540-23369a30a10fe         flow-ML
# 1295    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 166     test_01  8a8a6b73-c1d6-4819-9ae3-4b0038131b70           train
# 1       test_01  c06bc4ff-7384-48f3-9a0b-703b27d03933           train
# 656        7278  15df3483-1d20-44c8-9ed9-7a8a49cfcc1c           train
# 570        7278  6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d           train
# 1202       7278  d30dc88d-9b08-419b-b5a2-ae5ccfc78557           train
# 579        7676  06a90f93-d0e4-45fa-bd98-13678e749829           train
# 1577       5656  4fb7ae84-6ccd-48fd-9571-d65683a9e440           train
# 580        2434  26ca1a34-1ca5-4c48-80ee-7f040167b0d9           train
# 1104       2434  f9a85d54-1b7f-456a-aa6b-ff9aca727820           train
# 1106       5656  d06532ee-f09c-40d9-bf9b-1f406dc7ddfd           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 2             under_challenged     desktop         7.0   18.0          1788.0
# 1652          under_challenged     desktop         7.0   58.0          6143.0
# 497           under_challenged     desktop         7.0   63.0          6910.0
# 612            over_challenged     desktop         7.0   62.0          7595.0
# 162            over_challenged     desktop         7.0   69.0          8452.0
# 133   appropriately_challenged     desktop         7.0  102.0         12610.0
# 1254  appropriately_challenged     desktop         7.0  104.0         12680.0
# 1675  appropriately_challenged     desktop         7.0  105.0         12801.0
# 809           under_challenged     desktop         7.0   45.0          4062.0
# 1295          under_challenged     desktop         7.0   34.0          3477.0
# 166   appropriately_challenged      mobile         7.0    9.0           797.0
# 1     appropriately_challenged      mobile         7.0    8.0           677.0
# 656           under_challenged      mobile         7.0   31.0          2914.0
# 570   appropriately_challenged      mobile         7.0   -1.0           431.0
# 1202  appropriately_challenged      mobile         7.0   12.0          1727.0
# 579           under_challenged      mobile         7.0   20.0          2534.0
# 1577          under_challenged      mobile         7.0    3.0          1243.0
# 580            over_challenged      mobile         7.0    6.0          1295.0
# 1104  appropriately_challenged      mobile         7.0   10.0          1463.0
# 1106          under_challenged      mobile         7.0   27.0          2626.0
#
#       window_index
# 2              2.0
# 1652           8.0
# 497           10.0
# 612           13.0
# 162           15.0
# 133           24.0
# 1254          25.0
# 1675          26.0
# 809            7.0
# 1295           8.0
# 166            6.0
# 1              6.0
# 656            6.0
# 570            6.0
# 1202           6.0
# 579            6.0
# 1577           6.0
# 580            6.0
# 1104           6.0
# 1106           6.0
# Difficulty 8: 50 rows
#                                         id                       created_at  \
# 786   7441fdac-48ec-40c1-a1db-e7f0b20ce23c 2026-05-24 17:54:30.481490+00:00
# 1407  d3f7ba8f-2f9a-4db1-b18e-f9f4f9f85d56 2026-05-26 16:34:50.515295+00:00
# 82    0e8ce89f-0aeb-4e3e-978b-585ede25a4cd 2026-05-26 16:35:10.464358+00:00
# 210   20d77cd7-dfcd-4bda-a7ad-566cf94e8737 2026-05-26 16:35:20.470126+00:00
# 423   40f8e2ea-b6ac-42a7-833d-19658fdb1902 2026-05-26 18:36:54.809888+00:00
# 15    03949b13-87d5-4558-9595-044bf801a250 2026-05-26 20:14:04.513689+00:00
# 1552  e9dd23f5-703e-4411-bb8d-54f01279971e 2026-05-26 20:14:24.529763+00:00
# 534   4f033bd9-9085-4090-9800-3e24df5540e4 2026-05-26 20:16:04.510357+00:00
# 715   6a714ac4-fe6a-4254-a27e-a781a7758ff6 2026-05-28 18:43:00.325417+00:00
# 941   8a8f589c-3f13-40e3-8270-b1626b585989 2026-05-28 18:46:22.971576+00:00
# 611   59103fac-e9b2-404b-a7c7-8d5fea467694 2026-05-28 20:00:38.300489+00:00
# 235   24b82fa2-46a1-40bc-834b-490dceb7257a 2026-05-28 20:13:11.921541+00:00
# 1508  e4838777-2a75-4b7a-98f3-87e51d472835 2026-05-28 20:17:07.702649+00:00
# 644   5e2f8d47-3010-4605-955f-741bf3a11306 2026-05-30 11:33:26.888063+00:00
# 1639  f5618cf7-35f2-4de4-ba5f-5c621c9af1ef 2026-05-30 11:57:37.182657+00:00
# 1710  fee90b3d-b45c-4bd9-b52e-ff58f7a20c79 2026-05-30 11:57:39.878739+00:00
# 184   1cbe455d-3628-471d-baa7-607426f74eb2 2026-05-30 11:57:43.973065+00:00
# 1616  f33165e6-3734-4077-a077-63a804868c45 2026-05-30 12:02:16.475352+00:00
# 1633  f4b35973-9e79-4da1-bd4e-a792ddce8c97 2026-05-30 14:40:21.195142+00:00
# 1004  943fe365-66cd-4f31-91ea-a0bd355e935f 2026-05-30 14:40:39.331140+00:00
#
#      token_used                            session_id       game_mode  \
# 786     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 1407    test_01           1779813177540-23369a30a10fe  flow-heuristic
# 82      test_01           1779813177540-23369a30a10fe  flow-heuristic
# 210     test_01           1779813177540-23369a30a10fe  flow-heuristic
# 423     test_01           1779813177540-23369a30a10fe         flow-ML
# 15      test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 1552    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 534     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 715     test_01  8a8a6b73-c1d6-4819-9ae3-4b0038131b70           train
# 941     test_01  c06bc4ff-7384-48f3-9a0b-703b27d03933           train
# 611        7278  15df3483-1d20-44c8-9ed9-7a8a49cfcc1c           train
# 235        7278  6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d           train
# 1508       7278  d30dc88d-9b08-419b-b5a2-ae5ccfc78557           train
# 644     test_01  28e8dff4-1f9f-4bc8-a790-f9cf92f20764           train
# 1639       7676  06a90f93-d0e4-45fa-bd98-13678e749829           train
# 1710       5656  4fb7ae84-6ccd-48fd-9571-d65683a9e440           train
# 184        2434  26ca1a34-1ca5-4c48-80ee-7f040167b0d9           train
# 1616       2434  f9a85d54-1b7f-456a-aa6b-ff9aca727820           train
# 1633       5656  d06532ee-f09c-40d9-bf9b-1f406dc7ddfd           train
# 1004       7676  5d47e94b-d860-43ed-b550-b4c8f7f69686           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 786            over_challenged     desktop         8.0   22.0          2267.0
# 1407           over_challenged     desktop         8.0   61.0          6665.0
# 82    appropriately_challenged     desktop         8.0   64.0          7261.0
# 210            over_challenged     desktop         8.0   62.0          7386.0
# 423           under_challenged     desktop         8.0   50.0          4785.0
# 15            under_challenged     desktop         8.0   39.0          4280.0
# 1552          under_challenged     desktop         8.0   44.0          5053.0
# 534           under_challenged     desktop         8.0   73.0          9150.0
# 715   appropriately_challenged      mobile         8.0    9.0           797.0
# 941   appropriately_challenged      mobile         8.0    8.0           677.0
# 611           under_challenged      mobile         8.0   37.0          3570.0
# 235   appropriately_challenged      mobile         8.0   -1.0           431.0
# 1508  appropriately_challenged      mobile         8.0   12.0          1727.0
# 644   appropriately_challenged     desktop         8.0   11.0          1350.0
# 1639  appropriately_challenged      mobile         8.0   21.0          2916.0
# 1710           over_challenged      mobile         8.0    3.0          1372.0
# 184   appropriately_challenged      mobile         8.0    8.0          1455.0
# 1616           over_challenged      mobile         8.0    9.0          1576.0
# 1633          under_challenged      mobile         8.0   30.0          2878.0
# 1004  appropriately_challenged      mobile         8.0   16.0          2149.0
#
#       window_index
# 786            3.0
# 1407           9.0
# 82            11.0
# 210           12.0
# 423            8.0
# 15             9.0
# 1552          11.0
# 534           21.0
# 715            7.0
# 941            7.0
# 611            7.0
# 235            7.0
# 1508           7.0
# 644            4.0
# 1639           7.0
# 1710           7.0
# 184            7.0
# 1616           7.0
# 1633           7.0
# 1004           7.0
# Difficulty 9: 51 rows
#                                         id                       created_at  \
# 142   176a2dd6-73f2-4b5d-9acc-c028a2ee234e 2026-05-24 17:54:40.519171+00:00
# 1077  9f6fc6d3-9180-4849-adc7-49fd2c37ddce 2026-05-26 18:37:04.849545+00:00
# 755   6f5bba0b-c21d-446f-bd2d-b12e008aff26 2026-05-26 20:14:14.511790+00:00
# 930   87fb3d45-67fd-4329-8311-49bea118ff8b 2026-05-26 20:14:34.518858+00:00
# 238   251dbc2f-4df5-4ee2-8dd6-e63bd9259d0a 2026-05-26 20:14:44.513380+00:00
# 1119  a5319640-6ea4-4a62-a5ed-d7f22052fa85 2026-05-26 20:15:54.512564+00:00
# 172   1ace3b55-6ad4-4542-8959-09fd320c43e1 2026-05-26 20:16:14.528981+00:00
# 1115  a4789906-9173-47df-8c1e-6e437884234f 2026-05-26 20:17:04.503296+00:00
# 1009  94e78fb2-10fb-469d-b444-18c408cd3f12 2026-05-26 20:17:14.513469+00:00
# 598   576f8c90-c293-4ebe-9a77-b1b5971bf446 2026-05-28 18:43:10.329072+00:00
# 79    0e4c528d-03c4-42a8-aa84-ec246a97365f 2026-05-28 18:46:32.973140+00:00
# 1494  e28e0208-a5ac-4029-8a58-2da896345a88 2026-05-28 20:00:48.308481+00:00
# 140   16e553f9-9007-40f1-a193-03f829a30e1c 2026-05-28 20:13:21.947516+00:00
# 255   27d2a13a-2399-43f7-9160-8413cc23c903 2026-05-28 20:17:17.694447+00:00
# 1582  eea5d6c5-e5af-4549-a1ca-0dd2d86255a3 2026-05-30 11:34:55.873385+00:00
# 13    0302b4d4-b13a-4ca2-b011-0e94a1817d34 2026-05-30 11:57:47.177025+00:00
# 1476  e11285aa-573d-4dca-ba37-c0e2113029af 2026-05-30 11:57:49.876182+00:00
# 1308  c344b8da-e3d7-4f54-910f-0620d754b59b 2026-05-30 11:57:53.862802+00:00
# 569   542dd0d9-b758-4add-a22b-04ba6346565a 2026-05-30 12:02:26.455157+00:00
# 314   30b619e4-119c-4d68-9f5d-dc0851e5bd9b 2026-05-30 14:40:31.052983+00:00
#
#      token_used                            session_id       game_mode  \
# 142     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 1077    test_01           1779813177540-23369a30a10fe         flow-ML
# 755     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 930     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 238     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 1119    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 172     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 1115    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 1009    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 598     test_01  8a8a6b73-c1d6-4819-9ae3-4b0038131b70           train
# 79      test_01  c06bc4ff-7384-48f3-9a0b-703b27d03933           train
# 1494       7278  15df3483-1d20-44c8-9ed9-7a8a49cfcc1c           train
# 140        7278  6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d           train
# 255        7278  d30dc88d-9b08-419b-b5a2-ae5ccfc78557           train
# 1582    test_01  28e8dff4-1f9f-4bc8-a790-f9cf92f20764           train
# 13         7676  06a90f93-d0e4-45fa-bd98-13678e749829           train
# 1476       5656  4fb7ae84-6ccd-48fd-9571-d65683a9e440           train
# 1308       2434  26ca1a34-1ca5-4c48-80ee-7f040167b0d9           train
# 569        2434  f9a85d54-1b7f-456a-aa6b-ff9aca727820           train
# 314        5656  d06532ee-f09c-40d9-bf9b-1f406dc7ddfd           train
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 142           under_challenged     desktop         9.0   27.0          2695.0
# 1077          under_challenged     desktop         9.0   56.0          5320.0
# 755            over_challenged     desktop         9.0   39.0          4452.0
# 930   appropriately_challenged     desktop         9.0   47.0          5770.0
# 238           under_challenged     desktop         9.0   50.0          6159.0
# 1119           over_challenged     desktop         9.0   69.0          8736.0
# 172           under_challenged     desktop         9.0   82.0         10041.0
# 1115  appropriately_challenged     desktop         9.0   88.0         11433.0
# 1009          under_challenged     desktop         9.0   92.0         12042.0
# 598   appropriately_challenged      mobile         9.0    9.0           797.0
# 79    appropriately_challenged      mobile         9.0    8.0           677.0
# 1494          under_challenged      mobile         9.0   42.0          4186.0
# 140   appropriately_challenged      mobile         9.0   -1.0           431.0
# 255   appropriately_challenged      mobile         9.0   12.0          1727.0
# 1582          under_challenged     desktop         9.0   14.0          1758.0
# 13    appropriately_challenged      mobile         9.0   21.0          2925.0
# 1476  appropriately_challenged      mobile         9.0    5.0          1541.0
# 1308  appropriately_challenged      mobile         9.0    7.0          1738.0
# 569           under_challenged      mobile         9.0   10.0          1865.0
# 314   appropriately_challenged      mobile         9.0   30.0          3006.0
#
#       window_index
# 142            4.0
# 1077           9.0
# 755           10.0
# 930           12.0
# 238           13.0
# 1119          20.0
# 172           22.0
# 1115          27.0
# 1009          28.0
# 598            8.0
# 79             8.0
# 1494           8.0
# 140            8.0
# 255            8.0
# 1582           5.0
# 13             8.0
# 1476           8.0
# 1308           8.0
# 569            8.0
# 314            8.0
# Difficulty 10: 1,096 rows
#                                         id                       created_at  \
# 683   647f62f4-7753-4e6d-b8a9-e85e498df451 2026-05-24 17:54:50.474221+00:00
# 634   5c7abedd-6ca4-46b7-8307-f5b3bdc66a7a 2026-05-24 17:55:00.728640+00:00
# 1042  999658f1-04f8-4152-a8cf-11acde4622e7 2026-05-24 17:55:10.505907+00:00
# 1569  ec9ce3eb-7964-4a7b-a522-0ac9dfce0d86 2026-05-24 17:55:20.488203+00:00
# 932   88589950-7059-497f-87df-db499de056c3 2026-05-24 17:55:30.533001+00:00
# 1263  bbd4ce09-ff42-434b-a9da-3a3df0fc8f4f 2026-05-24 17:55:40.490019+00:00
# 858   7eccb254-9294-4046-a901-add26398f35b 2026-05-24 17:55:50.489190+00:00
# 782   738ad2d6-1c24-4d40-8d0b-796749d2d768 2026-05-24 17:56:00.493733+00:00
# 179   1be01473-578c-40fd-9dea-51404507b35e 2026-05-24 17:56:10.476296+00:00
# 476   47a0820b-b8c1-4643-ba86-bbeff6800ce9 2026-05-26 18:37:14.808806+00:00
# 603   581019bd-c6d7-42ff-b6cc-8b4597ebafef 2026-05-26 18:37:24.789980+00:00
# 1121  a5b12355-f6c0-47d6-871c-582be1c6105d 2026-05-26 18:37:34.807769+00:00
# 950   8bb4c3e4-1858-4843-9327-d0694fa46285 2026-05-26 18:37:44.802109+00:00
# 1492  e27e8dae-bc71-4d40-9220-9d417a8af1fd 2026-05-26 18:37:54.792969+00:00
# 399   3c887f47-541d-4eaa-a16c-a9f370712803 2026-05-26 18:38:04.842988+00:00
# 1576  ed74cb83-f7da-4f5d-8c09-ce63da669326 2026-05-26 20:14:54.527691+00:00
# 1339  c920fafd-de75-4ebe-abb4-14cab8eaeb53 2026-05-26 20:15:04.506879+00:00
# 989   91b4c7d9-36cc-4564-827a-fe10bd75c586 2026-05-26 20:15:14.501920+00:00
# 789   74a5b41d-68e1-4c81-bb62-bcaf20f5aeee 2026-05-26 20:15:24.502142+00:00
# 889   82780b77-1c89-4fce-9b8a-29023a5c1fc2 2026-05-26 20:15:34.501683+00:00
#
#      token_used                            session_id       game_mode  \
# 683     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 634     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 1042    test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 1569    test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 932     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 1263    test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 858     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 782     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 179     test_01  577f975f-9f61-4f50-bf5d-0628bc5c029e           train
# 476     test_01           1779813177540-23369a30a10fe         flow-ML
# 603     test_01           1779813177540-23369a30a10fe         flow-ML
# 1121    test_01           1779813177540-23369a30a10fe         flow-ML
# 950     test_01           1779813177540-23369a30a10fe         flow-ML
# 1492    test_01           1779813177540-23369a30a10fe         flow-ML
# 399     test_01           1779813177540-23369a30a10fe         flow-ML
# 1576    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 1339    test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 989     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 789     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
# 889     test_01          1779826329595-9fdf705124d1f8  flow-heuristic
#
#                challenge_label device_type  difficulty  score  height_climbed  \
# 683            over_challenged     desktop        10.0   27.0          2941.0
# 634           under_challenged     desktop        10.0   34.0          3769.0
# 1042          under_challenged     desktop        10.0   37.0          4066.0
# 1569          under_challenged     desktop        10.0   40.0          4358.0
# 932            over_challenged     desktop        10.0   40.0          4358.0
# 1263          under_challenged     desktop        10.0   45.0          4905.0
# 858   appropriately_challenged     desktop        10.0   50.0          5553.0
# 782   appropriately_challenged     desktop        10.0   54.0          6121.0
# 179           under_challenged     desktop        10.0   59.0          6756.0
# 476           under_challenged     desktop        10.0   61.0          6048.0
# 603           under_challenged     desktop        10.0   69.0          6910.0
# 1121          under_challenged     desktop        10.0   73.0          7575.0
# 950           under_challenged     desktop        10.0   76.0          7823.0
# 1492          under_challenged     desktop        10.0   78.0          8067.0
# 399            over_challenged     desktop        10.0   78.0          8067.0
# 1576          under_challenged     desktop        10.0   53.0          6488.0
# 1339          under_challenged     desktop        10.0   58.0          7029.0
# 989           under_challenged     desktop        10.0   61.0          7277.0
# 789           under_challenged     desktop        10.0   68.0          7983.0
# 889           under_challenged     desktop        10.0   72.0          8614.0
#
#       window_index
# 683            5.0
# 634            6.0
# 1042           7.0
# 1569           8.0
# 932            9.0
# 1263          10.0
# 858           11.0
# 782           12.0
# 179           13.0
# 476           10.0
# 603           11.0
# 1121          12.0
# 950           13.0
# 1492          14.0
# 399           15.0
# 1576          14.0
# 1339          15.0
# 989           16.0
# 789           17.0
# 889           18.0

# %% [markdown]
# ## Time played and time spent by challenge label

# %%
total_rows = len(windows)
total_seconds = total_rows * SECONDS_PER_ROW
print(f"Total telemetry windows: {total_rows:,}")
print(f"Total play time: {total_seconds:,} seconds | {total_seconds / 60:,.1f} minutes | {total_seconds / 3600:,.2f} hours")

label_time = (
    windows.groupby("challenge_label", dropna=False)
    .agg(rows=("id", "count"), sessions=("session_id", "nunique"), access_tokens=("token_used", "nunique"))
    .assign(
        play_seconds=lambda x: x["rows"] * SECONDS_PER_ROW,
        play_minutes=lambda x: x["play_seconds"] / 60,
        play_hours=lambda x: x["play_seconds"] / 3600,
        share=lambda x: x["rows"] / total_rows,
    )
    .sort_values("rows", ascending=False)
)
display(label_time)

session_time_stats = session_summary[["rows", "play_seconds", "play_minutes", "max_difficulty", "max_score", "max_height"]].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).T
token_time_stats = token_summary[["rows", "sessions", "play_seconds", "play_minutes", "max_difficulty", "max_score", "max_height"]].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).T

print("Session time/play stats")
display(session_time_stats)
print("Access token time/play stats")
display(token_time_stats)

session_label_time = pd.crosstab(windows["session_id"], windows["challenge_label"]) * SECONDS_PER_ROW
session_label_time = session_label_time.add_suffix("_seconds")
session_label_time["total_seconds"] = session_label_time.sum(axis=1)
display(session_label_time.sort_values("total_seconds", ascending=False).head(30))

token_label_time = pd.crosstab(windows["token_used"], windows["challenge_label"]) * SECONDS_PER_ROW
token_label_time = token_label_time.add_suffix("_seconds")
token_label_time["total_seconds"] = token_label_time.sum(axis=1)
display(token_label_time.sort_values("total_seconds", ascending=False))
# Out:
# Total telemetry windows: 1,716
# Total play time: 17,160 seconds | 286.0 minutes | 4.77 hours
#                           rows  sessions  access_tokens  play_seconds  \
# challenge_label
# appropriately_challenged   774        65             19          7740
# under_challenged           544        67             18          5440
# over_challenged            398        47             18          3980
#
#                           play_minutes  play_hours     share
# challenge_label
# appropriately_challenged    129.000000    2.150000  0.451049
# under_challenged             90.666667    1.511111  0.317016
# over_challenged              66.333333    1.105556  0.231935
# Session time/play stats
#                 count         mean          std        min          5%  \
# rows             77.0    22.285714    27.243472   1.000000    1.000000
# play_seconds     77.0   222.857143   272.434720  10.000000   10.000000
# play_minutes     77.0     3.714286     4.540579   0.166667    0.166667
# max_difficulty   77.0     7.038961     3.697231   1.000000    1.000000
# max_score        77.0    24.545455    34.398419  -1.000000    0.000000
# max_height       77.0  4172.272727  5346.173530   0.000000  130.000000
#
#                        25%          50%          75%           95%  \
# rows              4.000000    14.000000    28.000000     67.400000
# play_seconds     40.000000   140.000000   280.000000    674.000000
# play_minutes      0.666667     2.333333     4.666667     11.233333
# max_difficulty    3.000000    10.000000    10.000000     10.000000
# max_score         4.000000    12.000000    30.000000     94.600000
# max_height      887.000000  2149.000000  6425.000000  13011.800000
#
#                          max
# rows              137.000000
# play_seconds     1370.000000
# play_minutes       22.833333
# max_difficulty     10.000000
# max_score         202.000000
# max_height      30089.000000
# Access token time/play stats
#                 count         mean          std         min          5%  \
# rows             19.0    90.315789    81.678946   14.000000   17.600000
# sessions         19.0     4.052632     5.681096    1.000000    1.000000
# play_seconds     19.0   903.157895   816.789464  140.000000  176.000000
# play_minutes     19.0    15.052632    13.613158    2.333333    2.933333
# max_difficulty   19.0     9.736842     1.147079    5.000000    9.500000
# max_score        19.0    42.210526    54.886326    0.000000    0.000000
# max_height       19.0  8554.105263  7997.860602  450.000000  468.000000
#
#                     25%          50%      75%           95%           max
# rows              31.50    55.000000    120.0    257.600000    290.000000
# sessions           1.00     3.000000      4.0     10.700000     26.000000
# play_seconds     315.00   550.000000   1200.0   2576.000000   2900.000000
# play_minutes       5.25     9.166667     20.0     42.933333     48.333333
# max_difficulty    10.00    10.000000     10.0     10.000000     10.000000
# max_score          7.00    18.000000     47.5    142.600000    202.000000
# max_height      2403.50  7353.000000  10222.0  22275.200000  30089.000000
# challenge_label                       appropriately_challenged_seconds  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440                               540
# 56915d3a-01b4-437c-9166-b6d62b7da9db                               420
# aebf0163-b8df-45d1-b834-50d62e09591e                               520
# 1779812316142-1873bcf186bbc                                         10
# e59157d0-810f-41b2-92c2-436a1658f3eb                               400
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3                               260
# f9a85d54-1b7f-456a-aa6b-ff9aca727820                               410
# 5d47e94b-d860-43ed-b550-b4c8f7f69686                               200
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4                               200
# 06a90f93-d0e4-45fa-bd98-13678e749829                               280
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74                               380
# 83ae3cec-79b9-4c3b-966c-376d090b18b1                               160
# 1779813177540-23369a30a10fe                                         80
# 9c80face-f1d4-4cf1-b795-e7522cf68626                               210
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c                               190
# 1779826329595-9fdf705124d1f8                                        70
# 47967fdd-43cd-4f83-b165-2137e5d0863d                               290
# dc71c15c-9338-4a7b-8f44-b8610848bb2b                               110
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471                               300
# d31bcf45-c5f9-49c2-b279-51f999149198                               120
# 8952ae20-5054-4644-9dda-66dc1bf61776                                60
# 102b2e6a-c403-419b-b82e-626a8790dd79                               110
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9                               180
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd                               100
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2                                80
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd                               210
# 163931f4-ee12-42d5-ad52-c7a11345df25                               100
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d                               190
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70                               150
# a7e24744-5e70-4724-abfb-3a4af25d0531                                60
#
# challenge_label                       over_challenged_seconds  \
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440                      110
# 56915d3a-01b4-437c-9166-b6d62b7da9db                      730
# aebf0163-b8df-45d1-b834-50d62e09591e                      140
# 1779812316142-1873bcf186bbc                               840
# e59157d0-810f-41b2-92c2-436a1658f3eb                      120
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3                      270
# f9a85d54-1b7f-456a-aa6b-ff9aca727820                       90
# 5d47e94b-d860-43ed-b550-b4c8f7f69686                       40
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4                      170
# 06a90f93-d0e4-45fa-bd98-13678e749829                       50
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74                      130
# 83ae3cec-79b9-4c3b-966c-376d090b18b1                      170
# 1779813177540-23369a30a10fe                                80
# 9c80face-f1d4-4cf1-b795-e7522cf68626                       40
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c                       40
# 1779826329595-9fdf705124d1f8                               40
# 47967fdd-43cd-4f83-b165-2137e5d0863d                       20
# dc71c15c-9338-4a7b-8f44-b8610848bb2b                       70
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471                       20
# d31bcf45-c5f9-49c2-b279-51f999149198                      100
# 8952ae20-5054-4644-9dda-66dc1bf61776                       40
# 102b2e6a-c403-419b-b82e-626a8790dd79                       70
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9                       50
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd                       20
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2                       30
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd                       10
# 163931f4-ee12-42d5-ad52-c7a11345df25                      100
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d                       10
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70                       10
# a7e24744-5e70-4724-abfb-3a4af25d0531                       30
#
# challenge_label                       under_challenged_seconds  total_seconds
# session_id
# 4fb7ae84-6ccd-48fd-9571-d65683a9e440                       720           1370
# 56915d3a-01b4-437c-9166-b6d62b7da9db                        40           1190
# aebf0163-b8df-45d1-b834-50d62e09591e                       380           1040
# 1779812316142-1873bcf186bbc                                  0            850
# e59157d0-810f-41b2-92c2-436a1658f3eb                       110            630
# 3343f769-4b96-4a95-a086-65dcb0fbb2c3                        90            620
# f9a85d54-1b7f-456a-aa6b-ff9aca727820                        70            570
# 5d47e94b-d860-43ed-b550-b4c8f7f69686                       310            550
# 5da2d5b8-0e3e-4050-ab4a-dc000e1c5ec4                       180            550
# 06a90f93-d0e4-45fa-bd98-13678e749829                       210            540
# 9a06fe62-100f-46a8-8ceb-ff3f8fe5fb74                        10            520
# 83ae3cec-79b9-4c3b-966c-376d090b18b1                       110            440
# 1779813177540-23369a30a10fe                                270            430
# 9c80face-f1d4-4cf1-b795-e7522cf68626                       160            410
# 15df3483-1d20-44c8-9ed9-7a8a49cfcc1c                       130            360
# 1779826329595-9fdf705124d1f8                               240            350
# 47967fdd-43cd-4f83-b165-2137e5d0863d                        20            330
# dc71c15c-9338-4a7b-8f44-b8610848bb2b                       150            330
# fe6bfb22-3f0e-494a-8a00-781d8a4e2471                         0            320
# d31bcf45-c5f9-49c2-b279-51f999149198                        60            280
# 8952ae20-5054-4644-9dda-66dc1bf61776                       180            280
# 102b2e6a-c403-419b-b82e-626a8790dd79                        90            270
# 26ca1a34-1ca5-4c48-80ee-7f040167b0d9                        40            270
# 9c30a3ee-8f4d-498a-89db-f9893ac37abd                       140            260
# 3eed663a-fe50-4b64-88cf-b0d62449b3e2                       140            250
# 6e3a95fc-f457-4c06-a2ca-06c2f75264cd                         0            220
# 163931f4-ee12-42d5-ad52-c7a11345df25                        10            210
# 6a3ea210-7c4f-44d3-b9f2-b74e2ac63d2d                         0            200
# 8a8a6b73-c1d6-4819-9ae3-4b0038131b70                        40            200
# a7e24744-5e70-4724-abfb-3a4af25d0531                        90            180
# challenge_label  appropriately_challenged_seconds  over_challenged_seconds  \
# token_used
# test_01                                       680                     1050
# 5656                                          960                      190
# 2007                                          850                      320
# cupuashoe                                     800                      860
# jeannie                                       720                      230
# 7676                                          480                       90
# 2002                                          570                      290
# 2434                                          590                      140
# 7278                                          440                       60
# 2003                                          200                      170
# 2005                                          320                       60
# 2013                                          160                      170
# 2019                                          120                       70
# bea                                           300                       20
# 2001                                          260                       40
# 2015                                          100                      100
# claude                                         80                       90
# jaco                                           60                       30
# sas_1905                                       50                        0
#
# challenge_label  under_challenged_seconds  total_seconds
# token_used
# test_01                              1170           2900
# 5656                                 1390           2540
# 2007                                  670           1840
# cupuashoe                              70           1730
# jeannie                               360           1310
# 7676                                  520           1090
# 2002                                  110            970
# 2434                                  110            840
# 7278                                  160            660
# 2003                                  180            550
# 2005                                  150            530
# 2013                                  110            440
# 2019                                  230            420
# bea                                     0            320
# 2001                                   10            310
# 2015                                   10            210
# claude                                 10            180
# jaco                                   90            180
# sas_1905                               90            140

# %% [markdown]
# ## Challenge label by difficulty

# %%
difficulty_label_counts = pd.crosstab(windows["difficulty"], windows["challenge_label"], margins=True)
difficulty_label_share = pd.crosstab(windows["difficulty"], windows["challenge_label"], normalize="index").round(3)
display(difficulty_label_counts)
display(difficulty_label_share)

try:
    import matplotlib.pyplot as plt

    plot_counts = pd.crosstab(windows["difficulty"], windows["challenge_label"]).reindex(range(1, 11), fill_value=0)
    colors = {
        "over_challenged": "orange",
        "under_challenged": "blue",
        "appropriately_challenged": "green",
    }

    fig, ax = plt.subplots(figsize=(10, 5))
    for label, color in colors.items():
        if label in plot_counts:
            ax.plot(
                plot_counts.index,
                plot_counts[label],
                marker="o",
                linewidth=2,
                color=color,
                label=label.replace("_", " "),
            )

    ax.set_title("Challenge label counts by difficulty")
    ax.set_xlabel("Difficulty")
    ax.set_ylabel("Rows / 10-second windows")
    ax.set_xticks(range(1, 11))
    ax.grid(True, alpha=0.25)
    ax.legend()
    plt.show()
except ImportError:
    print("matplotlib is not installed in this environment; skipping challenge-label line chart.")
# Out:
# challenge_label  appropriately_challenged  over_challenged  under_challenged  \
# difficulty
# 1.0                                    37               85                53
# 2.0                                    29               11                30
# 3.0                                    23               11                27
# 4.0                                    29                4                21
# 5.0                                    24                5                25
# 6.0                                    28                6                19
# 7.0                                    26                8                18
# 8.0                                    20               11                19
# 9.0                                    25                5                21
# 10.0                                  533              252               311
# All                                   774              398               544
#
# challenge_label   All
# difficulty
# 1.0               175
# 2.0                70
# 3.0                61
# 4.0                54
# 5.0                54
# 6.0                53
# 7.0                52
# 8.0                50
# 9.0                51
# 10.0             1096
# All              1716
# challenge_label  appropriately_challenged  over_challenged  under_challenged
# difficulty
# 1.0                                 0.211            0.486             0.303
# 2.0                                 0.414            0.157             0.429
# 3.0                                 0.377            0.180             0.443
# 4.0                                 0.537            0.074             0.389
# 5.0                                 0.444            0.093             0.463
# 6.0                                 0.528            0.113             0.358
# 7.0                                 0.500            0.154             0.346
# 8.0                                 0.400            0.220             0.380
# 9.0                                 0.490            0.098             0.412
# 10.0                                0.486            0.230             0.284
